# %% [markdown]
# # KL By Removed

# %%
import numpy as np
from lib.utils import model_results_from_npz
import csv

# --------------------
# Config
# --------------------
SEEDS = [42, 602, 311, 637, 800, 543, 969, 122, 336, 93]
NUM_CLASSES = 100
EPOCHS = 50
REMOVED_CLASSES = [
    4, 7, 6, 11, 14, 15, 19, 24, 23, 25, 29, 30, 
    31, 36, 35, 39, 44, 41, 49, 48, 51, 53, 59, 57, 60, 61, 
    68, 67, 72, 71, 76, 77, 80, 84, 88, 85, 92, 94, 99, 97] # CIFAR-100
DIR_RETRAIN = "../results/cifar100/"
DIR_REDIS   = "../results/redis_cifar100/"
EPS = 1e-12

# --------------------
# Prepare CSV
# --------------------
csv_path = "../analytics/CIFAR100/kl/kl_per_removed.csv"
with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Seed", "Removed_Class", "KL_Forget", "KL_Retain", "KL_Whole"])

    # --------------------
    # Loop over seeds & removed classes
    # --------------------
    for seed in SEEDS:
        for removed_class in REMOVED_CLASSES:

            # Load models
            retrain_path = f"{DIR_RETRAIN}/cifar100_resnet18_s{seed}_e{EPOCHS}_r{removed_class}.npz"
            redis_path   = f"{DIR_REDIS}/cifar_resnet_s{seed}_e{EPOCHS}_rd{removed_class}.npz"

            model_retrain = model_results_from_npz(retrain_path, NUM_CLASSES)
            model_redis   = model_results_from_npz(redis_path, NUM_CLASSES)

            # --------------------
            # KL on forget class
            # --------------------
            conf_retrain_forget = model_retrain.confidences[removed_class]
            conf_redis_forget   = model_redis.confidences[removed_class]
            # Normalize safely
            conf_retrain_forget /= (conf_retrain_forget.sum(axis=1, keepdims=True) + EPS)
            conf_redis_forget   /= (conf_redis_forget.sum(axis=1, keepdims=True) + EPS)
            kl_forget = np.sum(conf_retrain_forget * np.log((conf_retrain_forget + EPS) / (conf_redis_forget + EPS)), axis=1).mean()

            # --------------------
            # KL on retain classes
            # --------------------
            retain_classes = [c for c in range(NUM_CLASSES) if c != removed_class]
            conf_retrain_retain = np.vstack([model_retrain.confidences[c] for c in retain_classes])
            conf_redis_retain   = np.vstack([model_redis.confidences[c]   for c in retain_classes])
            conf_retrain_retain /= (conf_retrain_retain.sum(axis=1, keepdims=True) + EPS)
            conf_redis_retain   /= (conf_redis_retain.sum(axis=1, keepdims=True) + EPS)
            kl_retain = np.sum(conf_retrain_retain * np.log((conf_retrain_retain + EPS) / (conf_redis_retain + EPS)), axis=1).mean()

            # --------------------
            # KL on whole dataset
            # --------------------
            conf_retrain_all = np.vstack([model_retrain.confidences[c] for c in range(NUM_CLASSES)])
            conf_redis_all   = np.vstack([model_redis.confidences[c]   for c in range(NUM_CLASSES)])
            conf_retrain_all /= (conf_retrain_all.sum(axis=1, keepdims=True) + EPS)
            conf_redis_all   /= (conf_redis_all.sum(axis=1, keepdims=True) + EPS)
            kl_whole = np.sum(conf_retrain_all * np.log((conf_retrain_all + EPS) / (conf_redis_all + EPS)), axis=1).mean()

            # Write row
            writer.writerow([seed, removed_class, kl_forget, kl_retain, kl_whole])
            print(f"Seed {seed}, Removed Class {removed_class} | KL Forget: {kl_forget:.6f}, KL Retain: {kl_retain:.6f}, KL Whole: {kl_whole:.6f}")

# Seed 93, Removed Class 61 | KL Forget: 0.847740, KL Retain: 0.554224, KL Whole: 0.557159
# Seed 93, Removed Class 68 | KL Forget: 0.696519, KL Retain: 0.558570, KL Whole: 0.559950
# Seed 93, Removed Class 67 | KL Forget: 1.199548, KL Retain: 0.551211, KL Whole: 0.557694
# Seed 93, Removed Class 72 | KL Forget: 0.999326, KL Retain: 0.532831, KL Whole: 0.537496
# Seed 93, Removed Class 71 | KL Forget: 0.789145, KL Retain: 0.575003, KL Whole: 0.577144
# Seed 93, Removed Class 76 | KL Forget: 1.117990, KL Retain: 0.558564, KL Whole: 0.564158
# Seed 93, Removed Class 77 | KL Forget: 1.500369, KL Retain: 0.549307, KL Whole: 0.558818
# Seed 93, Removed Class 80 | KL Forget: 1.357041, KL Retain: 0.539224, KL Whole: 0.547402
# Seed 93, Removed Class 84 | KL Forget: 1.120092, KL Retain: 0.546755, KL Whole: 0.552489
# Seed 93, Removed Class 88 | KL Forget: 1.065141, KL Retain: 0.556008, KL Whole: 0.561099
# Seed 93, Removed Class 85 | KL Forget: 1.357154, KL Retain: 0.556424, KL Whole: 0.564431
# Seed 93, Removed Class 92 | KL Forget: 0.882028, KL Retain: 0.560835, KL Whole: 0.564047
# Seed 93, Removed Class 94 | KL Forget: 0.974874, KL Retain: 0.567215, KL Whole: 0.571291
# Seed 93, Removed Class 99 | KL Forget: 1.092781, KL Retain: 0.557931, KL Whole: 0.563279
# Seed 93, Removed Class 97 | KL Forget: 1.234053, KL Retain: 0.553248, KL Whole: 0.560056
# CSV saved to ../analytics/CIFAR100/kl/kl_per_removed.csv

# %% [markdown]
# # KL Per Seed

# %%
import numpy as np
from lib.utils import model_results_from_npz
import csv

# --------------------
# Config
# --------------------
SEEDS = [42, 602, 311, 637, 800, 543, 969, 122, 336, 93]
NUM_CLASSES = 100
EPOCHS = 50
REMOVED_CLASSES = [
    4, 7, 6, 11, 14, 15, 19, 24, 23, 25, 29, 30, 
    31, 36, 35, 39, 44, 41, 49, 48, 51, 53, 59, 57, 60, 61, 
    68, 67, 72, 71, 76, 77, 80, 84, 88, 85, 92, 94, 99, 97] # CIFAR-100
DIR_RETRAIN = "../results/cifar100/"
DIR_REDIS   = "../results/redis_cifar100/"
EPS = 1e-12

# --------------------
# Prepare CSV
# --------------------
csv_path = "../analytics/CIFAR100/kl/kl_summary_per_seed.csv"
with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Seed", "KL_Forget_avg", "KL_Retain_avg", "KL_Whole_avg"])

    # --------------------
    # Loop over seeds
    # --------------------
    for seed in SEEDS:
        kl_forget_list, kl_retain_list, kl_whole_list = [], [], []

        for removed_class in REMOVED_CLASSES:
            # Load models
            retrain_path = f"{DIR_RETRAIN}/cifar100_resnet18_s{seed}_e{EPOCHS}_r{removed_class}.npz"
            redis_path   = f"{DIR_REDIS}/cifar_resnet_s{seed}_e{EPOCHS}_rd{removed_class}.npz"

            model_retrain = model_results_from_npz(retrain_path, NUM_CLASSES)
            model_redis   = model_results_from_npz(redis_path, NUM_CLASSES)

            # KL on forget class
            conf_retrain_forget = model_retrain.confidences[removed_class]
            conf_redis_forget   = model_redis.confidences[removed_class]
            conf_retrain_forget /= (conf_retrain_forget.sum(axis=1, keepdims=True) + EPS)
            conf_redis_forget   /= (conf_redis_forget.sum(axis=1, keepdims=True) + EPS)
            kl_forget_list.append(np.sum(conf_retrain_forget * np.log((conf_retrain_forget + EPS) / (conf_redis_forget + EPS)), axis=1).mean())

            # KL on retain classes
            retain_classes = [c for c in range(NUM_CLASSES) if c != removed_class]
            conf_retrain_retain = np.vstack([model_retrain.confidences[c] for c in retain_classes])
            conf_redis_retain   = np.vstack([model_redis.confidences[c]   for c in retain_classes])
            conf_retrain_retain /= (conf_retrain_retain.sum(axis=1, keepdims=True) + EPS)
            conf_redis_retain   /= (conf_redis_retain.sum(axis=1, keepdims=True) + EPS)
            kl_retain_list.append(np.sum(conf_retrain_retain * np.log((conf_retrain_retain + EPS) / (conf_redis_retain + EPS)), axis=1).mean())

            # KL on whole dataset
            conf_retrain_all = np.vstack([model_retrain.confidences[c] for c in range(NUM_CLASSES)])
            conf_redis_all   = np.vstack([model_redis.confidences[c]   for c in range(NUM_CLASSES)])
            conf_retrain_all /= (conf_retrain_all.sum(axis=1, keepdims=True) + EPS)
            conf_redis_all   /= (conf_redis_all.sum(axis=1, keepdims=True) + EPS)
            kl_whole_list.append(np.sum(conf_retrain_all * np.log((conf_retrain_all + EPS) / (conf_redis_all + EPS)), axis=1).mean())

        # Average over all removed classes for this seed
        kl_forget_avg = np.mean(kl_forget_list)
        kl_retain_avg = np.mean(kl_retain_list)
        kl_whole_avg  = np.mean(kl_whole_list)

        writer.writerow([seed, kl_forget_avg, kl_retain_avg, kl_whole_avg])
        print(f"Seed {seed} | KL Forget Avg: {kl_forget_avg:.6f}, KL Retain Avg: {kl_retain_avg:.6f}, KL Whole Avg: {kl_whole_avg:.6f}")

print(f"CSV saved to {csv_path}")
# Out:
# Seed 42 | KL Forget Avg: 1.163914, KL Retain Avg: 0.559588, KL Whole Avg: 0.565631
# Seed 602 | KL Forget Avg: 1.159101, KL Retain Avg: 0.563368, KL Whole Avg: 0.569325
# Seed 311 | KL Forget Avg: 1.135363, KL Retain Avg: 0.558440, KL Whole Avg: 0.564209
# Seed 637 | KL Forget Avg: 1.183099, KL Retain Avg: 0.567969, KL Whole Avg: 0.574120
# Seed 800 | KL Forget Avg: 1.167035, KL Retain Avg: 0.557740, KL Whole Avg: 0.563833
# Seed 543 | KL Forget Avg: 1.166650, KL Retain Avg: 0.558220, KL Whole Avg: 0.564304
# Seed 969 | KL Forget Avg: 1.172708, KL Retain Avg: 0.555213, KL Whole Avg: 0.561388
# Seed 122 | KL Forget Avg: 1.149785, KL Retain Avg: 0.554743, KL Whole Avg: 0.560693
# Seed 336 | KL Forget Avg: 1.168998, KL Retain Avg: 0.565023, KL Whole Avg: 0.571063
# Seed 93 | KL Forget Avg: 1.119879, KL Retain Avg: 0.552632, KL Whole Avg: 0.558304
# CSV saved to ../analytics/CIFAR100/kl/kl_summary_per_seed.csv

# %% [markdown]
# # KL Three-Way

# %%
# %%
import os
import numpy as np
import csv
from lib.utils import model_results_from_npz

# --------------------
# Config
# --------------------
SEEDS = [42, 602, 311, 637, 800, 543, 969, 122, 336, 93]
NUM_CLASSES = 100
EPOCHS = 50
REMOVED_CLASSES = [
    4, 7, 6, 11, 14, 15, 19, 24, 23, 25, 29, 30, 
    31, 36, 35, 39, 44, 41, 49, 48, 51, 53, 59, 57, 60, 61, 
    68, 67, 72, 71, 76, 77, 80, 84, 88, 85, 92, 94, 99, 97] # CIFAR-100
DIR_ORIG   = "../results/cifar100/"
DIR_RETRAIN = "../results/cifar100/"
DIR_REDIS   = "../results/redis_cifar100/"
EPS = 1e-12

# --------------------
# Output CSV
# --------------------
csv_path = "../analytics/CIFAR100/kl/kl_original_retrain_redis.csv"
os.makedirs(os.path.dirname(csv_path), exist_ok=True)

with open(csv_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow([
        "Seed", "Removed_Class",
        "KL_Orig_Redis_Forget", "KL_Orig_Redis_Retain",
        "KL_Orig_Retrain_Forget", "KL_Orig_Retrain_Retain",
        "KL_Redis_Retrain_Forget", "KL_Redis_Retrain_Retain"
    ])

    # --------------------
    # Loop over seeds & removed classes
    # --------------------
    for seed in SEEDS:
        print(f"\n=== Seed {seed} ===")
        for removed_class in REMOVED_CLASSES:
            # Paths
            orig_path    = f"{DIR_ORIG}/cifar100_resnet18_s{seed}_e{EPOCHS}.npz"
            retrain_path = f"{DIR_RETRAIN}/cifar100_resnet18_s{seed}_e{EPOCHS}_r{removed_class}.npz"
            redis_path   = f"{DIR_REDIS}/cifar_resnet_s{seed}_e{EPOCHS}_rd{removed_class}.npz"

            if not (os.path.exists(orig_path) and os.path.exists(retrain_path) and os.path.exists(redis_path)):
                print(f"  Skipping class {removed_class} — missing file.")
                continue

            # Load models
            model_orig    = model_results_from_npz(orig_path, NUM_CLASSES)
            model_retrain = model_results_from_npz(retrain_path, NUM_CLASSES)
            model_redis   = model_results_from_npz(redis_path, NUM_CLASSES)

            # --------------------
            # Helper function
            # --------------------
            def kl_between(conf_a, conf_b):
                conf_a = conf_a / (conf_a.sum(axis=1, keepdims=True) + EPS)
                conf_b = conf_b / (conf_b.sum(axis=1, keepdims=True) + EPS)
                return np.sum(conf_a * np.log((conf_a + EPS) / (conf_b + EPS)), axis=1).mean()

            # --------------------
            # Split into forget / retain subsets
            # --------------------
            retain_classes = [c for c in range(NUM_CLASSES) if c != removed_class]
            conf_orig_forget    = model_orig.confidences[removed_class]
            conf_retrain_forget = model_retrain.confidences[removed_class]
            conf_redis_forget   = model_redis.confidences[removed_class]
            conf_orig_retain    = np.vstack([model_orig.confidences[c] for c in retain_classes])
            conf_retrain_retain = np.vstack([model_retrain.confidences[c] for c in retain_classes])
            conf_redis_retain   = np.vstack([model_redis.confidences[c] for c in retain_classes])

            # --------------------
            # Compute all pairwise KL
            # --------------------
            kl_orig_redis_forget   = kl_between(conf_orig_forget,   conf_redis_forget)
            kl_orig_redis_retain   = kl_between(conf_orig_retain,   conf_redis_retain)
            kl_orig_retrain_forget = kl_between(conf_orig_forget,   conf_retrain_forget)
            kl_orig_retrain_retain = kl_between(conf_orig_retain,   conf_retrain_retain)
            kl_redis_retrain_forget = kl_between(conf_retrain_forget, conf_redis_forget)
            kl_redis_retrain_retain = kl_between(conf_retrain_retain, conf_redis_retain)

            # --------------------
            # Write to CSV
            # --------------------
            writer.writerow([
                seed, removed_class,
                kl_orig_redis_forget, kl_orig_redis_retain,
                kl_orig_retrain_forget, kl_orig_retrain_retain,
                kl_redis_retrain_forget, kl_redis_retrain_retain
            ])

            print(
                f"  Class {removed_class}: "
                f"O-Rd(F)={kl_orig_redis_forget:.3f}, O-Rd(R)={kl_orig_redis_retain:.3f} | "
                f"O-Rt(F)={kl_orig_retrain_forget:.3f}, O-Rt(R)={kl_orig_retrain_retain:.3f} | "
                f"Rd-Rt(F)={kl_redis_retrain_forget:.3f}, Rd-Rt(R)={kl_redis_retrain_retain:.3f}"
            )

print(f"\nCSV saved to {csv_path}")
# Out:
# === Seed 42 ===
#   Class 4: O-Rd(F)=15.246, O-Rd(R)=0.130 | O-Rt(F)=7.363, O-Rt(R)=0.609 | Rd-Rt(F)=1.268, Rd-Rt(R)=0.548
#   Class 7: O-Rd(F)=19.499, O-Rd(R)=0.075 | O-Rt(F)=9.118, O-Rt(R)=0.582 | Rd-Rt(F)=1.266, Rd-Rt(R)=0.548
#   Class 6: O-Rd(F)=21.079, O-Rd(R)=0.081 | O-Rt(F)=9.518, O-Rt(R)=0.592 | Rd-Rt(F)=1.236, Rd-Rt(R)=0.560
#   Class 11: O-Rd(F)=12.908, O-Rd(R)=0.142 | O-Rt(F)=7.142, O-Rt(R)=0.621 | Rd-Rt(F)=0.955, Rd-Rt(R)=0.547
#   Class 14: O-Rd(F)=16.543, O-Rd(R)=0.093 | O-Rt(F)=6.918, O-Rt(R)=0.588 | Rd-Rt(F)=1.222, Rd-Rt(R)=0.544
#   Class 15: O-Rd(F)=20.134, O-Rd(R)=0.080 | O-Rt(F)=8.751, O-Rt(R)=0.597 | Rd-Rt(F)=1.593, Rd-Rt(R)=0.560
#   Class 19: O-Rd(F)=17.756, O-Rd(R)=0.084 | O-Rt(F)=7.474, O-Rt(R)=0.581 | Rd-Rt(F)=1.250, Rd-Rt(R)=0.551
#   Class 24: O-Rd(F)=21.859, O-Rd(R)=0.036 | O-Rt(F)=11.057, O-Rt(R)=0.574 | Rd-Rt(F)=0.775, Rd-Rt(R)=0.555
#   Class 23: O-Rd(F)=22.578, O-Rd(R)=0.047 | O-Rt(F)=9.960, O-Rt(R)=0.593 | Rd-Rt(F)=1.156, Rd-Rt(R)=0.567
#   Class 25: O-Rd(F)=14.876, O-Rd(R)=0.089 | O-Rt(F)=6.329, O-Rt(R)=0.581 | Rd-Rt(F)=0.957, Rd-Rt(R)=0.558
#   Class 29: O-Rd(F)=17.343, O-Rd(R)=0.080 | O-Rt(F)=7.262, O-Rt(R)=0.585 | Rd-Rt(F)=1.344, Rd-Rt(R)=0.549
#   Class 30: O-Rd(F)=17.870, O-Rd(R)=0.073 | O-Rt(F)=9.660, O-Rt(R)=0.600 | Rd-Rt(F)=1.070, Rd-Rt(R)=0.555
#   Class 31: O-Rd(F)=18.290, O-Rd(R)=0.062 | O-Rt(F)=8.512, O-Rt(R)=0.601 | Rd-Rt(F)=1.265, Rd-Rt(R)=0.566
#   Class 36: O-Rd(F)=21.415, O-Rd(R)=0.056 | O-Rt(F)=9.229, O-Rt(R)=0.589 | Rd-Rt(F)=1.010, Rd-Rt(R)=0.566
#   Class 35: O-Rd(F)=13.672, O-Rd(R)=0.130 | O-Rt(F)=7.485, O-Rt(R)=0.613 | Rd-Rt(F)=0.896, Rd-Rt(R)=0.543
#   Class 39: O-Rd(F)=22.810, O-Rd(R)=0.032 | O-Rt(F)=9.429, O-Rt(R)=0.582 | Rd-Rt(F)=1.648, Rd-Rt(R)=0.571
#   Class 44: O-Rd(F)=13.086, O-Rd(R)=0.157 | O-Rt(F)=5.982, O-Rt(R)=0.608 | Rd-Rt(F)=1.435, Rd-Rt(R)=0.544
#   Class 41: O-Rd(F)=24.164, O-Rd(R)=0.039 | O-Rt(F)=9.725, O-Rt(R)=0.590 | Rd-Rt(F)=1.920, Rd-Rt(R)=0.577
#   Class 49: O-Rd(F)=23.157, O-Rd(R)=0.060 | O-Rt(F)=9.628, O-Rt(R)=0.600 | Rd-Rt(F)=1.244, Rd-Rt(R)=0.575
#   Class 48: O-Rd(F)=25.090, O-Rd(R)=0.057 | O-Rt(F)=12.361, O-Rt(R)=0.586 | Rd-Rt(F)=0.913, Rd-Rt(R)=0.572
#   Class 51: O-Rd(F)=19.584, O-Rd(R)=0.077 | O-Rt(F)=7.939, O-Rt(R)=0.593 | Rd-Rt(F)=1.641, Rd-Rt(R)=0.564
#   Class 53: O-Rd(F)=24.257, O-Rd(R)=0.049 | O-Rt(F)=11.422, O-Rt(R)=0.586 | Rd-Rt(F)=0.987, Rd-Rt(R)=0.565
#   Class 59: O-Rd(F)=18.594, O-Rd(R)=0.106 | O-Rt(F)=8.156, O-Rt(R)=0.599 | Rd-Rt(F)=0.856, Rd-Rt(R)=0.545
#   Class 57: O-Rd(F)=20.199, O-Rd(R)=0.077 | O-Rt(F)=8.608, O-Rt(R)=0.603 | Rd-Rt(F)=1.010, Rd-Rt(R)=0.570
#   Class 60: O-Rd(F)=23.103, O-Rd(R)=0.043 | O-Rt(F)=10.042, O-Rt(R)=0.581 | Rd-Rt(F)=0.995, Rd-Rt(R)=0.562
#   Class 61: O-Rd(F)=18.930, O-Rd(R)=0.073 | O-Rt(F)=9.302, O-Rt(R)=0.588 | Rd-Rt(F)=0.764, Rd-Rt(R)=0.562
#   Class 68: O-Rd(F)=24.913, O-Rd(R)=0.044 | O-Rt(F)=11.369, O-Rt(R)=0.578 | Rd-Rt(F)=0.909, Rd-Rt(R)=0.566
#   Class 67: O-Rd(F)=15.431, O-Rd(R)=0.092 | O-Rt(F)=7.473, O-Rt(R)=0.592 | Rd-Rt(F)=1.021, Rd-Rt(R)=0.549
#   Class 72: O-Rd(F)=11.376, O-Rd(R)=0.168 | O-Rt(F)=5.519, O-Rt(R)=0.608 | Rd-Rt(F)=1.091, Rd-Rt(R)=0.540
#   Class 71: O-Rd(F)=22.244, O-Rd(R)=0.067 | O-Rt(F)=10.627, O-Rt(R)=0.593 | Rd-Rt(F)=0.774, Rd-Rt(R)=0.563
#   Class 76: O-Rd(F)=23.885, O-Rd(R)=0.044 | O-Rt(F)=9.626, O-Rt(R)=0.596 | Rd-Rt(F)=1.120, Rd-Rt(R)=0.583
#   Class 77: O-Rd(F)=17.016, O-Rd(R)=0.081 | O-Rt(F)=7.451, O-Rt(R)=0.593 | Rd-Rt(F)=1.605, Rd-Rt(R)=0.555
#   Class 80: O-Rd(F)=16.257, O-Rd(R)=0.119 | O-Rt(F)=7.474, O-Rt(R)=0.602 | Rd-Rt(F)=1.336, Rd-Rt(R)=0.549
#   Class 84: O-Rd(F)=17.036, O-Rd(R)=0.076 | O-Rt(F)=7.014, O-Rt(R)=0.587 | Rd-Rt(F)=1.224, Rd-Rt(R)=0.550
#   Class 88: O-Rd(F)=21.193, O-Rd(R)=0.049 | O-Rt(F)=9.909, O-Rt(R)=0.577 | Rd-Rt(F)=1.074, Rd-Rt(R)=0.558
#   Class 85: O-Rd(F)=21.530, O-Rd(R)=0.052 | O-Rt(F)=8.530, O-Rt(R)=0.590 | Rd-Rt(F)=1.403, Rd-Rt(R)=0.569
#   Class 92: O-Rd(F)=17.608, O-Rd(R)=0.087 | O-Rt(F)=8.125, O-Rt(R)=0.604 | Rd-Rt(F)=0.935, Rd-Rt(R)=0.571
#   Class 94: O-Rd(F)=25.321, O-Rd(R)=0.035 | O-Rt(F)=9.868, O-Rt(R)=0.581 | Rd-Rt(F)=0.955, Rd-Rt(R)=0.570
#   Class 99: O-Rd(F)=17.810, O-Rd(R)=0.083 | O-Rt(F)=7.489, O-Rt(R)=0.599 | Rd-Rt(F)=1.165, Rd-Rt(R)=0.562
#   Class 97: O-Rd(F)=19.676, O-Rd(R)=0.061 | O-Rt(F)=8.231, O-Rt(R)=0.591 | Rd-Rt(F)=1.269, Rd-Rt(R)=0.574
#
# === Seed 602 ===
#   Class 4: O-Rd(F)=15.838, O-Rd(R)=0.142 | O-Rt(F)=7.512, O-Rt(R)=0.611 | Rd-Rt(F)=1.447, Rd-Rt(R)=0.555
#   Class 7: O-Rd(F)=19.631, O-Rd(R)=0.065 | O-Rt(F)=8.664, O-Rt(R)=0.584 | Rd-Rt(F)=1.234, Rd-Rt(R)=0.557
#   Class 6: O-Rd(F)=20.913, O-Rd(R)=0.061 | O-Rt(F)=9.091, O-Rt(R)=0.587 | Rd-Rt(F)=1.192, Rd-Rt(R)=0.566
#   Class 11: O-Rd(F)=12.641, O-Rd(R)=0.124 | O-Rt(F)=6.758, O-Rt(R)=0.623 | Rd-Rt(F)=0.896, Rd-Rt(R)=0.563
#   Class 14: O-Rd(F)=16.775, O-Rd(R)=0.092 | O-Rt(F)=7.077, O-Rt(R)=0.603 | Rd-Rt(F)=1.291, Rd-Rt(R)=0.555
#   Class 15: O-Rd(F)=20.486, O-Rd(R)=0.087 | O-Rt(F)=9.015, O-Rt(R)=0.601 | Rd-Rt(F)=1.326, Rd-Rt(R)=0.559
#   Class 19: O-Rd(F)=16.359, O-Rd(R)=0.070 | O-Rt(F)=7.416, O-Rt(R)=0.593 | Rd-Rt(F)=1.266, Rd-Rt(R)=0.563
#   Class 24: O-Rd(F)=22.556, O-Rd(R)=0.042 | O-Rt(F)=11.740, O-Rt(R)=0.589 | Rd-Rt(F)=0.884, Rd-Rt(R)=0.574
#   Class 23: O-Rd(F)=21.303, O-Rd(R)=0.046 | O-Rt(F)=9.482, O-Rt(R)=0.598 | Rd-Rt(F)=1.090, Rd-Rt(R)=0.579
#   Class 25: O-Rd(F)=15.750, O-Rd(R)=0.096 | O-Rt(F)=6.957, O-Rt(R)=0.599 | Rd-Rt(F)=1.217, Rd-Rt(R)=0.572
#   Class 29: O-Rd(F)=17.525, O-Rd(R)=0.079 | O-Rt(F)=7.161, O-Rt(R)=0.594 | Rd-Rt(F)=1.446, Rd-Rt(R)=0.555
#   Class 30: O-Rd(F)=17.260, O-Rd(R)=0.077 | O-Rt(F)=8.954, O-Rt(R)=0.601 | Rd-Rt(F)=0.825, Rd-Rt(R)=0.551
#   Class 31: O-Rd(F)=18.557, O-Rd(R)=0.074 | O-Rt(F)=8.709, O-Rt(R)=0.600 | Rd-Rt(F)=1.367, Rd-Rt(R)=0.564
#   Class 36: O-Rd(F)=21.733, O-Rd(R)=0.062 | O-Rt(F)=9.641, O-Rt(R)=0.598 | Rd-Rt(F)=1.129, Rd-Rt(R)=0.566
#   Class 35: O-Rd(F)=14.257, O-Rd(R)=0.133 | O-Rt(F)=7.308, O-Rt(R)=0.611 | Rd-Rt(F)=0.744, Rd-Rt(R)=0.549
#   Class 39: O-Rd(F)=21.859, O-Rd(R)=0.032 | O-Rt(F)=9.193, O-Rt(R)=0.591 | Rd-Rt(F)=1.465, Rd-Rt(R)=0.577
#   Class 44: O-Rd(F)=12.653, O-Rd(R)=0.168 | O-Rt(F)=5.726, O-Rt(R)=0.606 | Rd-Rt(F)=1.293, Rd-Rt(R)=0.538
#   Class 41: O-Rd(F)=24.191, O-Rd(R)=0.043 | O-Rt(F)=9.503, O-Rt(R)=0.579 | Rd-Rt(F)=1.416, Rd-Rt(R)=0.566
#   Class 49: O-Rd(F)=22.541, O-Rd(R)=0.053 | O-Rt(F)=9.282, O-Rt(R)=0.597 | Rd-Rt(F)=1.172, Rd-Rt(R)=0.575
#   Class 48: O-Rd(F)=24.574, O-Rd(R)=0.045 | O-Rt(F)=11.685, O-Rt(R)=0.596 | Rd-Rt(F)=0.884, Rd-Rt(R)=0.576
#   Class 51: O-Rd(F)=19.024, O-Rd(R)=0.088 | O-Rt(F)=7.924, O-Rt(R)=0.609 | Rd-Rt(F)=1.718, Rd-Rt(R)=0.572
#   Class 53: O-Rd(F)=24.286, O-Rd(R)=0.047 | O-Rt(F)=11.384, O-Rt(R)=0.595 | Rd-Rt(F)=1.114, Rd-Rt(R)=0.565
#   Class 59: O-Rd(F)=18.175, O-Rd(R)=0.095 | O-Rt(F)=8.122, O-Rt(R)=0.605 | Rd-Rt(F)=0.783, Rd-Rt(R)=0.565
#   Class 57: O-Rd(F)=20.255, O-Rd(R)=0.078 | O-Rt(F)=8.903, O-Rt(R)=0.603 | Rd-Rt(F)=1.134, Rd-Rt(R)=0.568
#   Class 60: O-Rd(F)=23.462, O-Rd(R)=0.049 | O-Rt(F)=10.347, O-Rt(R)=0.602 | Rd-Rt(F)=1.142, Rd-Rt(R)=0.577
#   Class 61: O-Rd(F)=18.338, O-Rd(R)=0.068 | O-Rt(F)=9.191, O-Rt(R)=0.603 | Rd-Rt(F)=0.855, Rd-Rt(R)=0.567
#   Class 68: O-Rd(F)=25.115, O-Rd(R)=0.034 | O-Rt(F)=11.329, O-Rt(R)=0.581 | Rd-Rt(F)=0.957, Rd-Rt(R)=0.560
#   Class 67: O-Rd(F)=15.834, O-Rd(R)=0.110 | O-Rt(F)=7.552, O-Rt(R)=0.605 | Rd-Rt(F)=1.197, Rd-Rt(R)=0.557
#   Class 72: O-Rd(F)=12.190, O-Rd(R)=0.167 | O-Rt(F)=5.834, O-Rt(R)=0.616 | Rd-Rt(F)=1.285, Rd-Rt(R)=0.554
#   Class 71: O-Rd(F)=21.829, O-Rd(R)=0.075 | O-Rt(F)=9.695, O-Rt(R)=0.595 | Rd-Rt(F)=0.618, Rd-Rt(R)=0.561
#   Class 76: O-Rd(F)=24.012, O-Rd(R)=0.037 | O-Rt(F)=9.740, O-Rt(R)=0.565 | Rd-Rt(F)=1.211, Rd-Rt(R)=0.560
#   Class 77: O-Rd(F)=16.847, O-Rd(R)=0.074 | O-Rt(F)=7.344, O-Rt(R)=0.599 | Rd-Rt(F)=1.411, Rd-Rt(R)=0.558
#   Class 80: O-Rd(F)=16.702, O-Rd(R)=0.115 | O-Rt(F)=7.939, O-Rt(R)=0.602 | Rd-Rt(F)=1.308, Rd-Rt(R)=0.556
#   Class 84: O-Rd(F)=16.789, O-Rd(R)=0.076 | O-Rt(F)=6.941, O-Rt(R)=0.588 | Rd-Rt(F)=1.217, Rd-Rt(R)=0.566
#   Class 88: O-Rd(F)=19.741, O-Rd(R)=0.047 | O-Rt(F)=9.147, O-Rt(R)=0.583 | Rd-Rt(F)=1.090, Rd-Rt(R)=0.563
#   Class 85: O-Rd(F)=21.608, O-Rd(R)=0.042 | O-Rt(F)=8.458, O-Rt(R)=0.582 | Rd-Rt(F)=1.407, Rd-Rt(R)=0.568
#   Class 92: O-Rd(F)=17.245, O-Rd(R)=0.077 | O-Rt(F)=7.669, O-Rt(R)=0.605 | Rd-Rt(F)=0.862, Rd-Rt(R)=0.553
#   Class 94: O-Rd(F)=24.372, O-Rd(R)=0.037 | O-Rt(F)=10.118, O-Rt(R)=0.590 | Rd-Rt(F)=1.002, Rd-Rt(R)=0.573
#   Class 99: O-Rd(F)=18.338, O-Rd(R)=0.069 | O-Rt(F)=7.581, O-Rt(R)=0.605 | Rd-Rt(F)=1.162, Rd-Rt(R)=0.568
#   Class 97: O-Rd(F)=20.518, O-Rd(R)=0.063 | O-Rt(F)=8.929, O-Rt(R)=0.595 | Rd-Rt(F)=1.308, Rd-Rt(R)=0.565
#
# === Seed 311 ===
#   Class 4: O-Rd(F)=16.260, O-Rd(R)=0.126 | O-Rt(F)=7.568, O-Rt(R)=0.609 | Rd-Rt(F)=1.313, Rd-Rt(R)=0.549
#   Class 7: O-Rd(F)=19.831, O-Rd(R)=0.088 | O-Rt(F)=9.033, O-Rt(R)=0.606 | Rd-Rt(F)=1.183, Rd-Rt(R)=0.563
#   Class 6: O-Rd(F)=20.644, O-Rd(R)=0.067 | O-Rt(F)=9.165, O-Rt(R)=0.592 | Rd-Rt(F)=1.315, Rd-Rt(R)=0.565
#   Class 11: O-Rd(F)=12.909, O-Rd(R)=0.138 | O-Rt(F)=6.854, O-Rt(R)=0.612 | Rd-Rt(F)=0.739, Rd-Rt(R)=0.546
#   Class 14: O-Rd(F)=16.620, O-Rd(R)=0.099 | O-Rt(F)=6.840, O-Rt(R)=0.607 | Rd-Rt(F)=1.292, Rd-Rt(R)=0.563
#   Class 15: O-Rd(F)=20.468, O-Rd(R)=0.080 | O-Rt(F)=8.736, O-Rt(R)=0.587 | Rd-Rt(F)=1.373, Rd-Rt(R)=0.551
#   Class 19: O-Rd(F)=17.185, O-Rd(R)=0.079 | O-Rt(F)=7.708, O-Rt(R)=0.590 | Rd-Rt(F)=1.288, Rd-Rt(R)=0.555
#   Class 24: O-Rd(F)=21.553, O-Rd(R)=0.046 | O-Rt(F)=11.386, O-Rt(R)=0.587 | Rd-Rt(F)=0.710, Rd-Rt(R)=0.563
#   Class 23: O-Rd(F)=21.459, O-Rd(R)=0.048 | O-Rt(F)=9.316, O-Rt(R)=0.587 | Rd-Rt(F)=0.881, Rd-Rt(R)=0.557
#   Class 25: O-Rd(F)=15.551, O-Rd(R)=0.101 | O-Rt(F)=6.900, O-Rt(R)=0.600 | Rd-Rt(F)=1.144, Rd-Rt(R)=0.558
#   Class 29: O-Rd(F)=18.279, O-Rd(R)=0.081 | O-Rt(F)=7.673, O-Rt(R)=0.573 | Rd-Rt(F)=1.515, Rd-Rt(R)=0.540
#   Class 30: O-Rd(F)=18.262, O-Rd(R)=0.077 | O-Rt(F)=9.979, O-Rt(R)=0.601 | Rd-Rt(F)=0.969, Rd-Rt(R)=0.564
#   Class 31: O-Rd(F)=18.307, O-Rd(R)=0.070 | O-Rt(F)=8.654, O-Rt(R)=0.584 | Rd-Rt(F)=1.255, Rd-Rt(R)=0.550
#   Class 36: O-Rd(F)=20.975, O-Rd(R)=0.053 | O-Rt(F)=9.254, O-Rt(R)=0.590 | Rd-Rt(F)=0.888, Rd-Rt(R)=0.582
#   Class 35: O-Rd(F)=13.170, O-Rd(R)=0.146 | O-Rt(F)=6.799, O-Rt(R)=0.631 | Rd-Rt(F)=0.849, Rd-Rt(R)=0.552
#   Class 39: O-Rd(F)=22.531, O-Rd(R)=0.036 | O-Rt(F)=9.201, O-Rt(R)=0.577 | Rd-Rt(F)=1.694, Rd-Rt(R)=0.571
#   Class 44: O-Rd(F)=13.176, O-Rd(R)=0.176 | O-Rt(F)=6.095, O-Rt(R)=0.610 | Rd-Rt(F)=1.327, Rd-Rt(R)=0.543
#   Class 41: O-Rd(F)=23.797, O-Rd(R)=0.049 | O-Rt(F)=9.313, O-Rt(R)=0.584 | Rd-Rt(F)=1.273, Rd-Rt(R)=0.555
#   Class 49: O-Rd(F)=22.293, O-Rd(R)=0.051 | O-Rt(F)=9.343, O-Rt(R)=0.600 | Rd-Rt(F)=1.244, Rd-Rt(R)=0.557
#   Class 48: O-Rd(F)=24.697, O-Rd(R)=0.047 | O-Rt(F)=11.778, O-Rt(R)=0.588 | Rd-Rt(F)=0.920, Rd-Rt(R)=0.553
#   Class 51: O-Rd(F)=18.691, O-Rd(R)=0.060 | O-Rt(F)=7.388, O-Rt(R)=0.574 | Rd-Rt(F)=1.614, Rd-Rt(R)=0.545
#   Class 53: O-Rd(F)=24.595, O-Rd(R)=0.049 | O-Rt(F)=11.222, O-Rt(R)=0.578 | Rd-Rt(F)=0.894, Rd-Rt(R)=0.562
#   Class 59: O-Rd(F)=18.655, O-Rd(R)=0.088 | O-Rt(F)=8.175, O-Rt(R)=0.594 | Rd-Rt(F)=0.855, Rd-Rt(R)=0.546
#   Class 57: O-Rd(F)=20.462, O-Rd(R)=0.086 | O-Rt(F)=8.787, O-Rt(R)=0.593 | Rd-Rt(F)=1.277, Rd-Rt(R)=0.556
#   Class 60: O-Rd(F)=23.782, O-Rd(R)=0.047 | O-Rt(F)=9.991, O-Rt(R)=0.585 | Rd-Rt(F)=1.020, Rd-Rt(R)=0.579
#   Class 61: O-Rd(F)=19.267, O-Rd(R)=0.073 | O-Rt(F)=10.131, O-Rt(R)=0.593 | Rd-Rt(F)=0.820, Rd-Rt(R)=0.559
#   Class 68: O-Rd(F)=24.802, O-Rd(R)=0.033 | O-Rt(F)=11.439, O-Rt(R)=0.575 | Rd-Rt(F)=0.928, Rd-Rt(R)=0.555
#   Class 67: O-Rd(F)=15.725, O-Rd(R)=0.095 | O-Rt(F)=7.728, O-Rt(R)=0.592 | Rd-Rt(F)=1.157, Rd-Rt(R)=0.544
#   Class 72: O-Rd(F)=12.506, O-Rd(R)=0.153 | O-Rt(F)=5.955, O-Rt(R)=0.615 | Rd-Rt(F)=0.988, Rd-Rt(R)=0.554
#   Class 71: O-Rd(F)=21.496, O-Rd(R)=0.069 | O-Rt(F)=10.160, O-Rt(R)=0.600 | Rd-Rt(F)=0.801, Rd-Rt(R)=0.563
#   Class 76: O-Rd(F)=23.625, O-Rd(R)=0.042 | O-Rt(F)=9.932, O-Rt(R)=0.581 | Rd-Rt(F)=1.232, Rd-Rt(R)=0.570
#   Class 77: O-Rd(F)=16.802, O-Rd(R)=0.072 | O-Rt(F)=7.290, O-Rt(R)=0.588 | Rd-Rt(F)=1.435, Rd-Rt(R)=0.564
#   Class 80: O-Rd(F)=15.702, O-Rd(R)=0.113 | O-Rt(F)=7.625, O-Rt(R)=0.599 | Rd-Rt(F)=1.595, Rd-Rt(R)=0.549
#   Class 84: O-Rd(F)=18.667, O-Rd(R)=0.068 | O-Rt(F)=7.577, O-Rt(R)=0.587 | Rd-Rt(F)=1.207, Rd-Rt(R)=0.552
#   Class 88: O-Rd(F)=20.496, O-Rd(R)=0.044 | O-Rt(F)=9.140, O-Rt(R)=0.585 | Rd-Rt(F)=1.028, Rd-Rt(R)=0.577
#   Class 85: O-Rd(F)=20.364, O-Rd(R)=0.051 | O-Rt(F)=8.344, O-Rt(R)=0.596 | Rd-Rt(F)=1.310, Rd-Rt(R)=0.573
#   Class 92: O-Rd(F)=16.897, O-Rd(R)=0.089 | O-Rt(F)=7.992, O-Rt(R)=0.597 | Rd-Rt(F)=0.879, Rd-Rt(R)=0.556
#   Class 94: O-Rd(F)=25.005, O-Rd(R)=0.042 | O-Rt(F)=10.284, O-Rt(R)=0.596 | Rd-Rt(F)=1.023, Rd-Rt(R)=0.571
#   Class 99: O-Rd(F)=17.727, O-Rd(R)=0.069 | O-Rt(F)=7.914, O-Rt(R)=0.587 | Rd-Rt(F)=0.970, Rd-Rt(R)=0.565
#   Class 97: O-Rd(F)=19.765, O-Rd(R)=0.069 | O-Rt(F)=8.426, O-Rt(R)=0.593 | Rd-Rt(F)=1.212, Rd-Rt(R)=0.558
#
# === Seed 637 ===
#   Class 4: O-Rd(F)=16.066, O-Rd(R)=0.136 | O-Rt(F)=7.423, O-Rt(R)=0.628 | Rd-Rt(F)=1.331, Rd-Rt(R)=0.562
#   Class 7: O-Rd(F)=19.743, O-Rd(R)=0.078 | O-Rt(F)=9.393, O-Rt(R)=0.592 | Rd-Rt(F)=1.378, Rd-Rt(R)=0.567
#   Class 6: O-Rd(F)=21.726, O-Rd(R)=0.069 | O-Rt(F)=9.424, O-Rt(R)=0.606 | Rd-Rt(F)=1.362, Rd-Rt(R)=0.567
#   Class 11: O-Rd(F)=12.538, O-Rd(R)=0.144 | O-Rt(F)=7.062, O-Rt(R)=0.635 | Rd-Rt(F)=0.848, Rd-Rt(R)=0.561
#   Class 14: O-Rd(F)=15.450, O-Rd(R)=0.082 | O-Rt(F)=6.790, O-Rt(R)=0.599 | Rd-Rt(F)=1.554, Rd-Rt(R)=0.558
#   Class 15: O-Rd(F)=19.706, O-Rd(R)=0.086 | O-Rt(F)=8.494, O-Rt(R)=0.603 | Rd-Rt(F)=1.451, Rd-Rt(R)=0.570
#   Class 19: O-Rd(F)=16.161, O-Rd(R)=0.077 | O-Rt(F)=7.278, O-Rt(R)=0.603 | Rd-Rt(F)=1.125, Rd-Rt(R)=0.557
#   Class 24: O-Rd(F)=21.845, O-Rd(R)=0.037 | O-Rt(F)=11.450, O-Rt(R)=0.605 | Rd-Rt(F)=0.899, Rd-Rt(R)=0.581
#   Class 23: O-Rd(F)=22.768, O-Rd(R)=0.053 | O-Rt(F)=10.176, O-Rt(R)=0.603 | Rd-Rt(F)=1.217, Rd-Rt(R)=0.580
#   Class 25: O-Rd(F)=14.752, O-Rd(R)=0.092 | O-Rt(F)=6.358, O-Rt(R)=0.595 | Rd-Rt(F)=1.083, Rd-Rt(R)=0.558
#   Class 29: O-Rd(F)=16.760, O-Rd(R)=0.070 | O-Rt(F)=7.016, O-Rt(R)=0.596 | Rd-Rt(F)=1.522, Rd-Rt(R)=0.570
#   Class 30: O-Rd(F)=16.285, O-Rd(R)=0.088 | O-Rt(F)=8.872, O-Rt(R)=0.625 | Rd-Rt(F)=1.000, Rd-Rt(R)=0.572
#   Class 31: O-Rd(F)=18.252, O-Rd(R)=0.071 | O-Rt(F)=8.518, O-Rt(R)=0.603 | Rd-Rt(F)=1.175, Rd-Rt(R)=0.571
#   Class 36: O-Rd(F)=21.450, O-Rd(R)=0.057 | O-Rt(F)=9.352, O-Rt(R)=0.602 | Rd-Rt(F)=1.304, Rd-Rt(R)=0.573
#   Class 35: O-Rd(F)=13.766, O-Rd(R)=0.127 | O-Rt(F)=7.078, O-Rt(R)=0.618 | Rd-Rt(F)=0.732, Rd-Rt(R)=0.554
#   Class 39: O-Rd(F)=22.352, O-Rd(R)=0.034 | O-Rt(F)=8.996, O-Rt(R)=0.587 | Rd-Rt(F)=1.595, Rd-Rt(R)=0.584
#   Class 44: O-Rd(F)=11.619, O-Rd(R)=0.174 | O-Rt(F)=5.568, O-Rt(R)=0.624 | Rd-Rt(F)=1.361, Rd-Rt(R)=0.554
#   Class 41: O-Rd(F)=23.860, O-Rd(R)=0.047 | O-Rt(F)=9.296, O-Rt(R)=0.575 | Rd-Rt(F)=1.342, Rd-Rt(R)=0.560
#   Class 49: O-Rd(F)=23.864, O-Rd(R)=0.062 | O-Rt(F)=9.832, O-Rt(R)=0.604 | Rd-Rt(F)=1.156, Rd-Rt(R)=0.563
#   Class 48: O-Rd(F)=25.128, O-Rd(R)=0.047 | O-Rt(F)=12.144, O-Rt(R)=0.601 | Rd-Rt(F)=0.849, Rd-Rt(R)=0.581
#   Class 51: O-Rd(F)=19.071, O-Rd(R)=0.088 | O-Rt(F)=7.974, O-Rt(R)=0.607 | Rd-Rt(F)=1.429, Rd-Rt(R)=0.558
#   Class 53: O-Rd(F)=23.887, O-Rd(R)=0.050 | O-Rt(F)=10.936, O-Rt(R)=0.595 | Rd-Rt(F)=0.905, Rd-Rt(R)=0.570
#   Class 59: O-Rd(F)=18.549, O-Rd(R)=0.113 | O-Rt(F)=8.193, O-Rt(R)=0.617 | Rd-Rt(F)=0.846, Rd-Rt(R)=0.565
#   Class 57: O-Rd(F)=21.079, O-Rd(R)=0.079 | O-Rt(F)=9.388, O-Rt(R)=0.603 | Rd-Rt(F)=1.402, Rd-Rt(R)=0.579
#   Class 60: O-Rd(F)=23.494, O-Rd(R)=0.044 | O-Rt(F)=10.325, O-Rt(R)=0.595 | Rd-Rt(F)=1.043, Rd-Rt(R)=0.578
#   Class 61: O-Rd(F)=19.405, O-Rd(R)=0.071 | O-Rt(F)=9.692, O-Rt(R)=0.601 | Rd-Rt(F)=0.860, Rd-Rt(R)=0.566
#   Class 68: O-Rd(F)=24.895, O-Rd(R)=0.035 | O-Rt(F)=11.456, O-Rt(R)=0.603 | Rd-Rt(F)=0.882, Rd-Rt(R)=0.597
#   Class 67: O-Rd(F)=14.623, O-Rd(R)=0.107 | O-Rt(F)=7.223, O-Rt(R)=0.613 | Rd-Rt(F)=1.118, Rd-Rt(R)=0.552
#   Class 72: O-Rd(F)=10.094, O-Rd(R)=0.137 | O-Rt(F)=5.165, O-Rt(R)=0.617 | Rd-Rt(F)=1.318, Rd-Rt(R)=0.558
#   Class 71: O-Rd(F)=21.834, O-Rd(R)=0.074 | O-Rt(F)=10.012, O-Rt(R)=0.617 | Rd-Rt(F)=0.876, Rd-Rt(R)=0.578
#   Class 76: O-Rd(F)=24.138, O-Rd(R)=0.040 | O-Rt(F)=9.997, O-Rt(R)=0.595 | Rd-Rt(F)=1.188, Rd-Rt(R)=0.574
#   Class 77: O-Rd(F)=16.580, O-Rd(R)=0.083 | O-Rt(F)=7.239, O-Rt(R)=0.601 | Rd-Rt(F)=1.525, Rd-Rt(R)=0.563
#   Class 80: O-Rd(F)=14.601, O-Rd(R)=0.107 | O-Rt(F)=7.251, O-Rt(R)=0.594 | Rd-Rt(F)=1.501, Rd-Rt(R)=0.541
#   Class 84: O-Rd(F)=17.581, O-Rd(R)=0.065 | O-Rt(F)=7.243, O-Rt(R)=0.598 | Rd-Rt(F)=1.205, Rd-Rt(R)=0.562
#   Class 88: O-Rd(F)=20.478, O-Rd(R)=0.043 | O-Rt(F)=9.189, O-Rt(R)=0.594 | Rd-Rt(F)=1.100, Rd-Rt(R)=0.574
#   Class 85: O-Rd(F)=20.681, O-Rd(R)=0.046 | O-Rt(F)=8.196, O-Rt(R)=0.589 | Rd-Rt(F)=1.316, Rd-Rt(R)=0.567
#   Class 92: O-Rd(F)=16.425, O-Rd(R)=0.088 | O-Rt(F)=7.743, O-Rt(R)=0.610 | Rd-Rt(F)=0.865, Rd-Rt(R)=0.568
#   Class 94: O-Rd(F)=25.068, O-Rd(R)=0.038 | O-Rt(F)=10.199, O-Rt(R)=0.588 | Rd-Rt(F)=1.016, Rd-Rt(R)=0.579
#   Class 99: O-Rd(F)=18.279, O-Rd(R)=0.064 | O-Rt(F)=7.912, O-Rt(R)=0.607 | Rd-Rt(F)=1.143, Rd-Rt(R)=0.572
#   Class 97: O-Rd(F)=18.399, O-Rd(R)=0.053 | O-Rt(F)=8.274, O-Rt(R)=0.600 | Rd-Rt(F)=1.502, Rd-Rt(R)=0.576
#
# === Seed 800 ===
#   Class 4: O-Rd(F)=15.872, O-Rd(R)=0.143 | O-Rt(F)=7.182, O-Rt(R)=0.615 | Rd-Rt(F)=1.333, Rd-Rt(R)=0.551
#   Class 7: O-Rd(F)=18.263, O-Rd(R)=0.091 | O-Rt(F)=8.570, O-Rt(R)=0.593 | Rd-Rt(F)=1.348, Rd-Rt(R)=0.550
#   Class 6: O-Rd(F)=20.694, O-Rd(R)=0.068 | O-Rt(F)=9.304, O-Rt(R)=0.594 | Rd-Rt(F)=1.497, Rd-Rt(R)=0.556
#   Class 11: O-Rd(F)=11.913, O-Rd(R)=0.146 | O-Rt(F)=6.214, O-Rt(R)=0.619 | Rd-Rt(F)=0.863, Rd-Rt(R)=0.537
#   Class 14: O-Rd(F)=16.823, O-Rd(R)=0.094 | O-Rt(F)=6.938, O-Rt(R)=0.604 | Rd-Rt(F)=1.289, Rd-Rt(R)=0.559
#   Class 15: O-Rd(F)=20.299, O-Rd(R)=0.077 | O-Rt(F)=8.977, O-Rt(R)=0.598 | Rd-Rt(F)=1.275, Rd-Rt(R)=0.559
#   Class 19: O-Rd(F)=16.563, O-Rd(R)=0.067 | O-Rt(F)=7.264, O-Rt(R)=0.580 | Rd-Rt(F)=1.331, Rd-Rt(R)=0.546
#   Class 24: O-Rd(F)=22.283, O-Rd(R)=0.046 | O-Rt(F)=11.821, O-Rt(R)=0.589 | Rd-Rt(F)=0.914, Rd-Rt(R)=0.569
#   Class 23: O-Rd(F)=22.126, O-Rd(R)=0.048 | O-Rt(F)=9.799, O-Rt(R)=0.604 | Rd-Rt(F)=0.903, Rd-Rt(R)=0.582
#   Class 25: O-Rd(F)=15.001, O-Rd(R)=0.096 | O-Rt(F)=6.554, O-Rt(R)=0.600 | Rd-Rt(F)=1.039, Rd-Rt(R)=0.563
#   Class 29: O-Rd(F)=17.827, O-Rd(R)=0.090 | O-Rt(F)=7.387, O-Rt(R)=0.584 | Rd-Rt(F)=1.666, Rd-Rt(R)=0.549
#   Class 30: O-Rd(F)=17.196, O-Rd(R)=0.083 | O-Rt(F)=9.240, O-Rt(R)=0.597 | Rd-Rt(F)=0.862, Rd-Rt(R)=0.554
#   Class 31: O-Rd(F)=18.851, O-Rd(R)=0.068 | O-Rt(F)=8.687, O-Rt(R)=0.588 | Rd-Rt(F)=1.186, Rd-Rt(R)=0.555
#   Class 36: O-Rd(F)=21.208, O-Rd(R)=0.067 | O-Rt(F)=9.826, O-Rt(R)=0.585 | Rd-Rt(F)=1.148, Rd-Rt(R)=0.555
#   Class 35: O-Rd(F)=13.374, O-Rd(R)=0.146 | O-Rt(F)=7.160, O-Rt(R)=0.621 | Rd-Rt(F)=0.805, Rd-Rt(R)=0.544
#   Class 39: O-Rd(F)=22.570, O-Rd(R)=0.029 | O-Rt(F)=9.025, O-Rt(R)=0.575 | Rd-Rt(F)=1.444, Rd-Rt(R)=0.563
#   Class 44: O-Rd(F)=11.644, O-Rd(R)=0.186 | O-Rt(F)=5.679, O-Rt(R)=0.618 | Rd-Rt(F)=1.504, Rd-Rt(R)=0.541
#   Class 41: O-Rd(F)=23.997, O-Rd(R)=0.037 | O-Rt(F)=9.516, O-Rt(R)=0.579 | Rd-Rt(F)=1.613, Rd-Rt(R)=0.565
#   Class 49: O-Rd(F)=22.784, O-Rd(R)=0.050 | O-Rt(F)=9.581, O-Rt(R)=0.593 | Rd-Rt(F)=1.183, Rd-Rt(R)=0.570
#   Class 48: O-Rd(F)=25.446, O-Rd(R)=0.036 | O-Rt(F)=12.426, O-Rt(R)=0.581 | Rd-Rt(F)=0.843, Rd-Rt(R)=0.573
#   Class 51: O-Rd(F)=19.323, O-Rd(R)=0.072 | O-Rt(F)=7.890, O-Rt(R)=0.592 | Rd-Rt(F)=1.690, Rd-Rt(R)=0.555
#   Class 53: O-Rd(F)=24.522, O-Rd(R)=0.046 | O-Rt(F)=11.528, O-Rt(R)=0.596 | Rd-Rt(F)=1.044, Rd-Rt(R)=0.563
#   Class 59: O-Rd(F)=18.734, O-Rd(R)=0.084 | O-Rt(F)=8.285, O-Rt(R)=0.588 | Rd-Rt(F)=0.800, Rd-Rt(R)=0.552
#   Class 57: O-Rd(F)=20.309, O-Rd(R)=0.087 | O-Rt(F)=8.492, O-Rt(R)=0.598 | Rd-Rt(F)=1.178, Rd-Rt(R)=0.558
#   Class 60: O-Rd(F)=22.940, O-Rd(R)=0.052 | O-Rt(F)=10.359, O-Rt(R)=0.595 | Rd-Rt(F)=1.031, Rd-Rt(R)=0.569
#   Class 61: O-Rd(F)=17.712, O-Rd(R)=0.063 | O-Rt(F)=8.752, O-Rt(R)=0.598 | Rd-Rt(F)=0.936, Rd-Rt(R)=0.559
#   Class 68: O-Rd(F)=24.771, O-Rd(R)=0.034 | O-Rt(F)=11.280, O-Rt(R)=0.577 | Rd-Rt(F)=0.841, Rd-Rt(R)=0.576
#   Class 67: O-Rd(F)=15.513, O-Rd(R)=0.109 | O-Rt(F)=7.508, O-Rt(R)=0.606 | Rd-Rt(F)=1.127, Rd-Rt(R)=0.557
#   Class 72: O-Rd(F)=11.285, O-Rd(R)=0.147 | O-Rt(F)=5.486, O-Rt(R)=0.608 | Rd-Rt(F)=1.130, Rd-Rt(R)=0.538
#   Class 71: O-Rd(F)=21.869, O-Rd(R)=0.069 | O-Rt(F)=10.092, O-Rt(R)=0.590 | Rd-Rt(F)=0.635, Rd-Rt(R)=0.566
#   Class 76: O-Rd(F)=24.535, O-Rd(R)=0.044 | O-Rt(F)=10.184, O-Rt(R)=0.591 | Rd-Rt(F)=1.181, Rd-Rt(R)=0.577
#   Class 77: O-Rd(F)=16.520, O-Rd(R)=0.081 | O-Rt(F)=6.969, O-Rt(R)=0.594 | Rd-Rt(F)=1.427, Rd-Rt(R)=0.558
#   Class 80: O-Rd(F)=15.184, O-Rd(R)=0.108 | O-Rt(F)=7.378, O-Rt(R)=0.595 | Rd-Rt(F)=1.417, Rd-Rt(R)=0.551
#   Class 84: O-Rd(F)=16.997, O-Rd(R)=0.064 | O-Rt(F)=7.138, O-Rt(R)=0.567 | Rd-Rt(F)=1.372, Rd-Rt(R)=0.548
#   Class 88: O-Rd(F)=21.482, O-Rd(R)=0.056 | O-Rt(F)=9.594, O-Rt(R)=0.585 | Rd-Rt(F)=1.160, Rd-Rt(R)=0.555
#   Class 85: O-Rd(F)=20.828, O-Rd(R)=0.043 | O-Rt(F)=8.330, O-Rt(R)=0.581 | Rd-Rt(F)=1.560, Rd-Rt(R)=0.552
#   Class 92: O-Rd(F)=16.909, O-Rd(R)=0.090 | O-Rt(F)=7.522, O-Rt(R)=0.594 | Rd-Rt(F)=0.733, Rd-Rt(R)=0.557
#   Class 94: O-Rd(F)=25.232, O-Rd(R)=0.040 | O-Rt(F)=10.246, O-Rt(R)=0.588 | Rd-Rt(F)=0.945, Rd-Rt(R)=0.565
#   Class 99: O-Rd(F)=18.409, O-Rd(R)=0.072 | O-Rt(F)=7.796, O-Rt(R)=0.585 | Rd-Rt(F)=1.005, Rd-Rt(R)=0.554
#   Class 97: O-Rd(F)=19.793, O-Rd(R)=0.065 | O-Rt(F)=8.615, O-Rt(R)=0.594 | Rd-Rt(F)=1.421, Rd-Rt(R)=0.558
#
# === Seed 543 ===
#   Class 4: O-Rd(F)=15.336, O-Rd(R)=0.140 | O-Rt(F)=7.067, O-Rt(R)=0.608 | Rd-Rt(F)=1.492, Rd-Rt(R)=0.552
#   Class 7: O-Rd(F)=20.148, O-Rd(R)=0.080 | O-Rt(F)=9.460, O-Rt(R)=0.592 | Rd-Rt(F)=1.204, Rd-Rt(R)=0.560
#   Class 6: O-Rd(F)=20.465, O-Rd(R)=0.088 | O-Rt(F)=8.896, O-Rt(R)=0.599 | Rd-Rt(F)=1.434, Rd-Rt(R)=0.555
#   Class 11: O-Rd(F)=12.005, O-Rd(R)=0.136 | O-Rt(F)=6.671, O-Rt(R)=0.618 | Rd-Rt(F)=0.799, Rd-Rt(R)=0.553
#   Class 14: O-Rd(F)=16.082, O-Rd(R)=0.081 | O-Rt(F)=6.793, O-Rt(R)=0.606 | Rd-Rt(F)=1.469, Rd-Rt(R)=0.570
#   Class 15: O-Rd(F)=20.168, O-Rd(R)=0.078 | O-Rt(F)=8.507, O-Rt(R)=0.605 | Rd-Rt(F)=1.301, Rd-Rt(R)=0.552
#   Class 19: O-Rd(F)=16.662, O-Rd(R)=0.078 | O-Rt(F)=7.554, O-Rt(R)=0.601 | Rd-Rt(F)=1.239, Rd-Rt(R)=0.563
#   Class 24: O-Rd(F)=21.797, O-Rd(R)=0.038 | O-Rt(F)=11.286, O-Rt(R)=0.576 | Rd-Rt(F)=0.925, Rd-Rt(R)=0.565
#   Class 23: O-Rd(F)=22.111, O-Rd(R)=0.050 | O-Rt(F)=9.549, O-Rt(R)=0.597 | Rd-Rt(F)=1.026, Rd-Rt(R)=0.578
#   Class 25: O-Rd(F)=15.167, O-Rd(R)=0.102 | O-Rt(F)=6.639, O-Rt(R)=0.593 | Rd-Rt(F)=1.007, Rd-Rt(R)=0.547
#   Class 29: O-Rd(F)=17.713, O-Rd(R)=0.088 | O-Rt(F)=7.650, O-Rt(R)=0.584 | Rd-Rt(F)=1.561, Rd-Rt(R)=0.549
#   Class 30: O-Rd(F)=18.372, O-Rd(R)=0.074 | O-Rt(F)=9.914, O-Rt(R)=0.598 | Rd-Rt(F)=0.864, Rd-Rt(R)=0.553
#   Class 31: O-Rd(F)=17.571, O-Rd(R)=0.057 | O-Rt(F)=8.265, O-Rt(R)=0.593 | Rd-Rt(F)=1.184, Rd-Rt(R)=0.561
#   Class 36: O-Rd(F)=21.452, O-Rd(R)=0.062 | O-Rt(F)=9.395, O-Rt(R)=0.593 | Rd-Rt(F)=1.215, Rd-Rt(R)=0.553
#   Class 35: O-Rd(F)=14.092, O-Rd(R)=0.155 | O-Rt(F)=7.458, O-Rt(R)=0.626 | Rd-Rt(F)=0.754, Rd-Rt(R)=0.540
#   Class 39: O-Rd(F)=22.594, O-Rd(R)=0.031 | O-Rt(F)=9.399, O-Rt(R)=0.581 | Rd-Rt(F)=1.664, Rd-Rt(R)=0.562
#   Class 44: O-Rd(F)=12.649, O-Rd(R)=0.167 | O-Rt(F)=5.635, O-Rt(R)=0.610 | Rd-Rt(F)=1.336, Rd-Rt(R)=0.541
#   Class 41: O-Rd(F)=23.444, O-Rd(R)=0.042 | O-Rt(F)=9.633, O-Rt(R)=0.594 | Rd-Rt(F)=1.436, Rd-Rt(R)=0.565
#   Class 49: O-Rd(F)=22.274, O-Rd(R)=0.052 | O-Rt(F)=9.281, O-Rt(R)=0.581 | Rd-Rt(F)=1.270, Rd-Rt(R)=0.549
#   Class 48: O-Rd(F)=25.402, O-Rd(R)=0.050 | O-Rt(F)=12.151, O-Rt(R)=0.596 | Rd-Rt(F)=0.890, Rd-Rt(R)=0.575
#   Class 51: O-Rd(F)=18.900, O-Rd(R)=0.073 | O-Rt(F)=7.596, O-Rt(R)=0.585 | Rd-Rt(F)=1.616, Rd-Rt(R)=0.557
#   Class 53: O-Rd(F)=24.806, O-Rd(R)=0.047 | O-Rt(F)=11.297, O-Rt(R)=0.595 | Rd-Rt(F)=1.003, Rd-Rt(R)=0.569
#   Class 59: O-Rd(F)=17.952, O-Rd(R)=0.087 | O-Rt(F)=7.812, O-Rt(R)=0.609 | Rd-Rt(F)=0.891, Rd-Rt(R)=0.562
#   Class 57: O-Rd(F)=20.298, O-Rd(R)=0.069 | O-Rt(F)=8.879, O-Rt(R)=0.595 | Rd-Rt(F)=1.136, Rd-Rt(R)=0.575
#   Class 60: O-Rd(F)=23.589, O-Rd(R)=0.046 | O-Rt(F)=10.439, O-Rt(R)=0.590 | Rd-Rt(F)=1.102, Rd-Rt(R)=0.563
#   Class 61: O-Rd(F)=18.749, O-Rd(R)=0.072 | O-Rt(F)=9.829, O-Rt(R)=0.596 | Rd-Rt(F)=0.845, Rd-Rt(R)=0.553
#   Class 68: O-Rd(F)=25.112, O-Rd(R)=0.033 | O-Rt(F)=11.545, O-Rt(R)=0.588 | Rd-Rt(F)=0.953, Rd-Rt(R)=0.573
#   Class 67: O-Rd(F)=16.414, O-Rd(R)=0.103 | O-Rt(F)=8.011, O-Rt(R)=0.603 | Rd-Rt(F)=0.988, Rd-Rt(R)=0.555
#   Class 72: O-Rd(F)=11.926, O-Rd(R)=0.162 | O-Rt(F)=6.221, O-Rt(R)=0.613 | Rd-Rt(F)=1.187, Rd-Rt(R)=0.540
#   Class 71: O-Rd(F)=22.265, O-Rd(R)=0.065 | O-Rt(F)=10.107, O-Rt(R)=0.598 | Rd-Rt(F)=0.707, Rd-Rt(R)=0.567
#   Class 76: O-Rd(F)=24.062, O-Rd(R)=0.034 | O-Rt(F)=9.981, O-Rt(R)=0.583 | Rd-Rt(F)=1.191, Rd-Rt(R)=0.570
#   Class 77: O-Rd(F)=17.635, O-Rd(R)=0.078 | O-Rt(F)=7.664, O-Rt(R)=0.595 | Rd-Rt(F)=1.475, Rd-Rt(R)=0.554
#   Class 80: O-Rd(F)=16.288, O-Rd(R)=0.122 | O-Rt(F)=7.654, O-Rt(R)=0.610 | Rd-Rt(F)=1.402, Rd-Rt(R)=0.544
#   Class 84: O-Rd(F)=17.276, O-Rd(R)=0.062 | O-Rt(F)=7.253, O-Rt(R)=0.585 | Rd-Rt(F)=1.381, Rd-Rt(R)=0.563
#   Class 88: O-Rd(F)=21.221, O-Rd(R)=0.054 | O-Rt(F)=9.272, O-Rt(R)=0.577 | Rd-Rt(F)=1.234, Rd-Rt(R)=0.548
#   Class 85: O-Rd(F)=21.261, O-Rd(R)=0.055 | O-Rt(F)=8.356, O-Rt(R)=0.584 | Rd-Rt(F)=1.280, Rd-Rt(R)=0.555
#   Class 92: O-Rd(F)=16.707, O-Rd(R)=0.087 | O-Rt(F)=7.869, O-Rt(R)=0.602 | Rd-Rt(F)=0.924, Rd-Rt(R)=0.562
#   Class 94: O-Rd(F)=24.956, O-Rd(R)=0.042 | O-Rt(F)=10.351, O-Rt(R)=0.580 | Rd-Rt(F)=0.993, Rd-Rt(R)=0.566
#   Class 99: O-Rd(F)=18.691, O-Rd(R)=0.065 | O-Rt(F)=8.065, O-Rt(R)=0.589 | Rd-Rt(F)=1.127, Rd-Rt(R)=0.559
#   Class 97: O-Rd(F)=20.260, O-Rd(R)=0.068 | O-Rt(F)=8.639, O-Rt(R)=0.589 | Rd-Rt(F)=1.161, Rd-Rt(R)=0.555
#
# === Seed 969 ===
#   Class 4: O-Rd(F)=15.488, O-Rd(R)=0.134 | O-Rt(F)=7.206, O-Rt(R)=0.623 | Rd-Rt(F)=1.373, Rd-Rt(R)=0.557
#   Class 7: O-Rd(F)=19.598, O-Rd(R)=0.091 | O-Rt(F)=8.909, O-Rt(R)=0.596 | Rd-Rt(F)=1.198, Rd-Rt(R)=0.551
#   Class 6: O-Rd(F)=21.815, O-Rd(R)=0.086 | O-Rt(F)=9.500, O-Rt(R)=0.577 | Rd-Rt(F)=1.140, Rd-Rt(R)=0.545
#   Class 11: O-Rd(F)=12.966, O-Rd(R)=0.134 | O-Rt(F)=6.930, O-Rt(R)=0.612 | Rd-Rt(F)=0.857, Rd-Rt(R)=0.542
#   Class 14: O-Rd(F)=15.862, O-Rd(R)=0.095 | O-Rt(F)=6.917, O-Rt(R)=0.592 | Rd-Rt(F)=1.468, Rd-Rt(R)=0.552
#   Class 15: O-Rd(F)=20.114, O-Rd(R)=0.092 | O-Rt(F)=8.752, O-Rt(R)=0.614 | Rd-Rt(F)=1.355, Rd-Rt(R)=0.557
#   Class 19: O-Rd(F)=17.775, O-Rd(R)=0.078 | O-Rt(F)=8.082, O-Rt(R)=0.584 | Rd-Rt(F)=1.484, Rd-Rt(R)=0.544
#   Class 24: O-Rd(F)=22.229, O-Rd(R)=0.039 | O-Rt(F)=11.476, O-Rt(R)=0.578 | Rd-Rt(F)=0.733, Rd-Rt(R)=0.556
#   Class 23: O-Rd(F)=22.015, O-Rd(R)=0.051 | O-Rt(F)=9.527, O-Rt(R)=0.595 | Rd-Rt(F)=1.060, Rd-Rt(R)=0.569
#   Class 25: O-Rd(F)=16.329, O-Rd(R)=0.116 | O-Rt(F)=6.990, O-Rt(R)=0.604 | Rd-Rt(F)=1.039, Rd-Rt(R)=0.552
#   Class 29: O-Rd(F)=17.650, O-Rd(R)=0.074 | O-Rt(F)=7.564, O-Rt(R)=0.590 | Rd-Rt(F)=1.597, Rd-Rt(R)=0.554
#   Class 30: O-Rd(F)=17.123, O-Rd(R)=0.075 | O-Rt(F)=9.185, O-Rt(R)=0.610 | Rd-Rt(F)=0.785, Rd-Rt(R)=0.561
#   Class 31: O-Rd(F)=17.265, O-Rd(R)=0.074 | O-Rt(F)=7.979, O-Rt(R)=0.592 | Rd-Rt(F)=1.181, Rd-Rt(R)=0.548
#   Class 36: O-Rd(F)=20.235, O-Rd(R)=0.058 | O-Rt(F)=9.133, O-Rt(R)=0.592 | Rd-Rt(F)=1.050, Rd-Rt(R)=0.557
#   Class 35: O-Rd(F)=13.385, O-Rd(R)=0.130 | O-Rt(F)=6.801, O-Rt(R)=0.618 | Rd-Rt(F)=0.755, Rd-Rt(R)=0.546
#   Class 39: O-Rd(F)=22.222, O-Rd(R)=0.036 | O-Rt(F)=9.096, O-Rt(R)=0.590 | Rd-Rt(F)=1.638, Rd-Rt(R)=0.562
#   Class 44: O-Rd(F)=12.848, O-Rd(R)=0.173 | O-Rt(F)=5.928, O-Rt(R)=0.615 | Rd-Rt(F)=1.466, Rd-Rt(R)=0.540
#   Class 41: O-Rd(F)=23.542, O-Rd(R)=0.032 | O-Rt(F)=9.106, O-Rt(R)=0.568 | Rd-Rt(F)=1.425, Rd-Rt(R)=0.558
#   Class 49: O-Rd(F)=23.247, O-Rd(R)=0.053 | O-Rt(F)=9.812, O-Rt(R)=0.599 | Rd-Rt(F)=1.185, Rd-Rt(R)=0.572
#   Class 48: O-Rd(F)=25.317, O-Rd(R)=0.043 | O-Rt(F)=12.285, O-Rt(R)=0.597 | Rd-Rt(F)=1.000, Rd-Rt(R)=0.567
#   Class 51: O-Rd(F)=17.979, O-Rd(R)=0.070 | O-Rt(F)=7.093, O-Rt(R)=0.584 | Rd-Rt(F)=1.487, Rd-Rt(R)=0.555
#   Class 53: O-Rd(F)=24.558, O-Rd(R)=0.042 | O-Rt(F)=11.110, O-Rt(R)=0.596 | Rd-Rt(F)=1.190, Rd-Rt(R)=0.562
#   Class 59: O-Rd(F)=18.660, O-Rd(R)=0.099 | O-Rt(F)=8.256, O-Rt(R)=0.595 | Rd-Rt(F)=0.936, Rd-Rt(R)=0.544
#   Class 57: O-Rd(F)=20.446, O-Rd(R)=0.084 | O-Rt(F)=9.039, O-Rt(R)=0.584 | Rd-Rt(F)=1.375, Rd-Rt(R)=0.547
#   Class 60: O-Rd(F)=23.529, O-Rd(R)=0.051 | O-Rt(F)=9.967, O-Rt(R)=0.601 | Rd-Rt(F)=1.107, Rd-Rt(R)=0.577
#   Class 61: O-Rd(F)=18.419, O-Rd(R)=0.061 | O-Rt(F)=9.122, O-Rt(R)=0.578 | Rd-Rt(F)=0.830, Rd-Rt(R)=0.552
#   Class 68: O-Rd(F)=25.156, O-Rd(R)=0.031 | O-Rt(F)=11.726, O-Rt(R)=0.602 | Rd-Rt(F)=0.809, Rd-Rt(R)=0.580
#   Class 67: O-Rd(F)=15.357, O-Rd(R)=0.112 | O-Rt(F)=7.392, O-Rt(R)=0.600 | Rd-Rt(F)=1.318, Rd-Rt(R)=0.555
#   Class 72: O-Rd(F)=11.257, O-Rd(R)=0.140 | O-Rt(F)=5.536, O-Rt(R)=0.591 | Rd-Rt(F)=0.980, Rd-Rt(R)=0.523
#   Class 71: O-Rd(F)=21.988, O-Rd(R)=0.059 | O-Rt(F)=10.322, O-Rt(R)=0.589 | Rd-Rt(F)=0.777, Rd-Rt(R)=0.544
#   Class 76: O-Rd(F)=23.703, O-Rd(R)=0.040 | O-Rt(F)=9.563, O-Rt(R)=0.579 | Rd-Rt(F)=1.055, Rd-Rt(R)=0.555
#   Class 77: O-Rd(F)=16.817, O-Rd(R)=0.069 | O-Rt(F)=7.303, O-Rt(R)=0.595 | Rd-Rt(F)=1.394, Rd-Rt(R)=0.566
#   Class 80: O-Rd(F)=14.952, O-Rd(R)=0.090 | O-Rt(F)=7.130, O-Rt(R)=0.611 | Rd-Rt(F)=1.449, Rd-Rt(R)=0.560
#   Class 84: O-Rd(F)=18.134, O-Rd(R)=0.059 | O-Rt(F)=7.697, O-Rt(R)=0.582 | Rd-Rt(F)=1.299, Rd-Rt(R)=0.546
#   Class 88: O-Rd(F)=20.940, O-Rd(R)=0.062 | O-Rt(F)=9.710, O-Rt(R)=0.597 | Rd-Rt(F)=1.067, Rd-Rt(R)=0.566
#   Class 85: O-Rd(F)=22.010, O-Rd(R)=0.049 | O-Rt(F)=8.690, O-Rt(R)=0.591 | Rd-Rt(F)=1.505, Rd-Rt(R)=0.560
#   Class 92: O-Rd(F)=17.570, O-Rd(R)=0.087 | O-Rt(F)=8.311, O-Rt(R)=0.603 | Rd-Rt(F)=0.859, Rd-Rt(R)=0.566
#   Class 94: O-Rd(F)=24.860, O-Rd(R)=0.040 | O-Rt(F)=9.949, O-Rt(R)=0.584 | Rd-Rt(F)=1.008, Rd-Rt(R)=0.557
#   Class 99: O-Rd(F)=18.790, O-Rd(R)=0.075 | O-Rt(F)=8.305, O-Rt(R)=0.608 | Rd-Rt(F)=1.199, Rd-Rt(R)=0.555
#   Class 97: O-Rd(F)=19.728, O-Rd(R)=0.069 | O-Rt(F)=8.327, O-Rt(R)=0.586 | Rd-Rt(F)=1.479, Rd-Rt(R)=0.552
#
# === Seed 122 ===
#   Class 4: O-Rd(F)=15.533, O-Rd(R)=0.153 | O-Rt(F)=7.562, O-Rt(R)=0.618 | Rd-Rt(F)=1.299, Rd-Rt(R)=0.552
#   Class 7: O-Rd(F)=18.469, O-Rd(R)=0.063 | O-Rt(F)=8.644, O-Rt(R)=0.583 | Rd-Rt(F)=1.221, Rd-Rt(R)=0.550
#   Class 6: O-Rd(F)=19.978, O-Rd(R)=0.074 | O-Rt(F)=8.818, O-Rt(R)=0.595 | Rd-Rt(F)=1.015, Rd-Rt(R)=0.571
#   Class 11: O-Rd(F)=12.601, O-Rd(R)=0.137 | O-Rt(F)=7.043, O-Rt(R)=0.623 | Rd-Rt(F)=0.749, Rd-Rt(R)=0.550
#   Class 14: O-Rd(F)=17.468, O-Rd(R)=0.080 | O-Rt(F)=7.481, O-Rt(R)=0.580 | Rd-Rt(F)=1.472, Rd-Rt(R)=0.546
#   Class 15: O-Rd(F)=21.031, O-Rd(R)=0.089 | O-Rt(F)=9.174, O-Rt(R)=0.586 | Rd-Rt(F)=1.160, Rd-Rt(R)=0.549
#   Class 19: O-Rd(F)=17.141, O-Rd(R)=0.073 | O-Rt(F)=7.625, O-Rt(R)=0.589 | Rd-Rt(F)=1.292, Rd-Rt(R)=0.550
#   Class 24: O-Rd(F)=21.653, O-Rd(R)=0.041 | O-Rt(F)=11.964, O-Rt(R)=0.572 | Rd-Rt(F)=0.959, Rd-Rt(R)=0.554
#   Class 23: O-Rd(F)=22.307, O-Rd(R)=0.047 | O-Rt(F)=9.727, O-Rt(R)=0.573 | Rd-Rt(F)=0.994, Rd-Rt(R)=0.557
#   Class 25: O-Rd(F)=15.775, O-Rd(R)=0.092 | O-Rt(F)=6.929, O-Rt(R)=0.591 | Rd-Rt(F)=1.141, Rd-Rt(R)=0.560
#   Class 29: O-Rd(F)=17.757, O-Rd(R)=0.075 | O-Rt(F)=7.335, O-Rt(R)=0.581 | Rd-Rt(F)=1.388, Rd-Rt(R)=0.551
#   Class 30: O-Rd(F)=17.487, O-Rd(R)=0.079 | O-Rt(F)=9.125, O-Rt(R)=0.600 | Rd-Rt(F)=0.860, Rd-Rt(R)=0.559
#   Class 31: O-Rd(F)=17.526, O-Rd(R)=0.066 | O-Rt(F)=8.380, O-Rt(R)=0.585 | Rd-Rt(F)=1.198, Rd-Rt(R)=0.552
#   Class 36: O-Rd(F)=21.021, O-Rd(R)=0.054 | O-Rt(F)=9.235, O-Rt(R)=0.583 | Rd-Rt(F)=1.195, Rd-Rt(R)=0.565
#   Class 35: O-Rd(F)=14.581, O-Rd(R)=0.136 | O-Rt(F)=7.718, O-Rt(R)=0.612 | Rd-Rt(F)=0.717, Rd-Rt(R)=0.547
#   Class 39: O-Rd(F)=22.839, O-Rd(R)=0.034 | O-Rt(F)=9.181, O-Rt(R)=0.574 | Rd-Rt(F)=1.650, Rd-Rt(R)=0.549
#   Class 44: O-Rd(F)=13.306, O-Rd(R)=0.161 | O-Rt(F)=6.223, O-Rt(R)=0.605 | Rd-Rt(F)=1.380, Rd-Rt(R)=0.539
#   Class 41: O-Rd(F)=24.326, O-Rd(R)=0.042 | O-Rt(F)=9.534, O-Rt(R)=0.573 | Rd-Rt(F)=1.723, Rd-Rt(R)=0.554
#   Class 49: O-Rd(F)=23.022, O-Rd(R)=0.049 | O-Rt(F)=9.588, O-Rt(R)=0.582 | Rd-Rt(F)=1.084, Rd-Rt(R)=0.557
#   Class 48: O-Rd(F)=24.903, O-Rd(R)=0.046 | O-Rt(F)=11.683, O-Rt(R)=0.582 | Rd-Rt(F)=0.950, Rd-Rt(R)=0.560
#   Class 51: O-Rd(F)=19.341, O-Rd(R)=0.071 | O-Rt(F)=8.126, O-Rt(R)=0.596 | Rd-Rt(F)=1.503, Rd-Rt(R)=0.561
#   Class 53: O-Rd(F)=25.005, O-Rd(R)=0.052 | O-Rt(F)=11.499, O-Rt(R)=0.582 | Rd-Rt(F)=0.861, Rd-Rt(R)=0.553
#   Class 59: O-Rd(F)=18.273, O-Rd(R)=0.097 | O-Rt(F)=7.879, O-Rt(R)=0.606 | Rd-Rt(F)=1.001, Rd-Rt(R)=0.569
#   Class 57: O-Rd(F)=20.780, O-Rd(R)=0.079 | O-Rt(F)=8.856, O-Rt(R)=0.581 | Rd-Rt(F)=0.970, Rd-Rt(R)=0.565
#   Class 60: O-Rd(F)=24.094, O-Rd(R)=0.045 | O-Rt(F)=10.823, O-Rt(R)=0.574 | Rd-Rt(F)=1.096, Rd-Rt(R)=0.547
#   Class 61: O-Rd(F)=18.456, O-Rd(R)=0.059 | O-Rt(F)=9.425, O-Rt(R)=0.584 | Rd-Rt(F)=1.026, Rd-Rt(R)=0.556
#   Class 68: O-Rd(F)=25.280, O-Rd(R)=0.032 | O-Rt(F)=11.363, O-Rt(R)=0.589 | Rd-Rt(F)=0.932, Rd-Rt(R)=0.568
#   Class 67: O-Rd(F)=16.516, O-Rd(R)=0.105 | O-Rt(F)=8.160, O-Rt(R)=0.594 | Rd-Rt(F)=1.162, Rd-Rt(R)=0.549
#   Class 72: O-Rd(F)=12.453, O-Rd(R)=0.156 | O-Rt(F)=6.101, O-Rt(R)=0.604 | Rd-Rt(F)=1.184, Rd-Rt(R)=0.537
#   Class 71: O-Rd(F)=21.570, O-Rd(R)=0.064 | O-Rt(F)=10.004, O-Rt(R)=0.578 | Rd-Rt(F)=0.776, Rd-Rt(R)=0.553
#   Class 76: O-Rd(F)=24.371, O-Rd(R)=0.048 | O-Rt(F)=10.111, O-Rt(R)=0.588 | Rd-Rt(F)=1.196, Rd-Rt(R)=0.564
#   Class 77: O-Rd(F)=17.425, O-Rd(R)=0.075 | O-Rt(F)=7.504, O-Rt(R)=0.585 | Rd-Rt(F)=1.619, Rd-Rt(R)=0.553
#   Class 80: O-Rd(F)=15.697, O-Rd(R)=0.123 | O-Rt(F)=7.520, O-Rt(R)=0.583 | Rd-Rt(F)=1.283, Rd-Rt(R)=0.535
#   Class 84: O-Rd(F)=16.365, O-Rd(R)=0.065 | O-Rt(F)=6.997, O-Rt(R)=0.591 | Rd-Rt(F)=1.274, Rd-Rt(R)=0.558
#   Class 88: O-Rd(F)=20.843, O-Rd(R)=0.056 | O-Rt(F)=9.397, O-Rt(R)=0.575 | Rd-Rt(F)=0.946, Rd-Rt(R)=0.554
#   Class 85: O-Rd(F)=21.598, O-Rd(R)=0.043 | O-Rt(F)=8.450, O-Rt(R)=0.588 | Rd-Rt(F)=1.354, Rd-Rt(R)=0.564
#   Class 92: O-Rd(F)=16.392, O-Rd(R)=0.092 | O-Rt(F)=7.754, O-Rt(R)=0.601 | Rd-Rt(F)=0.988, Rd-Rt(R)=0.563
#   Class 94: O-Rd(F)=24.954, O-Rd(R)=0.036 | O-Rt(F)=10.331, O-Rt(R)=0.570 | Rd-Rt(F)=1.075, Rd-Rt(R)=0.562
#   Class 99: O-Rd(F)=18.353, O-Rd(R)=0.075 | O-Rt(F)=7.919, O-Rt(R)=0.600 | Rd-Rt(F)=1.015, Rd-Rt(R)=0.565
#   Class 97: O-Rd(F)=20.327, O-Rd(R)=0.068 | O-Rt(F)=8.685, O-Rt(R)=0.580 | Rd-Rt(F)=1.283, Rd-Rt(R)=0.544
#
# === Seed 336 ===
#   Class 4: O-Rd(F)=16.291, O-Rd(R)=0.115 | O-Rt(F)=7.472, O-Rt(R)=0.603 | Rd-Rt(F)=1.208, Rd-Rt(R)=0.561
#   Class 7: O-Rd(F)=19.896, O-Rd(R)=0.071 | O-Rt(F)=9.046, O-Rt(R)=0.596 | Rd-Rt(F)=1.052, Rd-Rt(R)=0.563
#   Class 6: O-Rd(F)=20.618, O-Rd(R)=0.086 | O-Rt(F)=9.289, O-Rt(R)=0.585 | Rd-Rt(F)=1.416, Rd-Rt(R)=0.559
#   Class 11: O-Rd(F)=12.819, O-Rd(R)=0.147 | O-Rt(F)=7.196, O-Rt(R)=0.612 | Rd-Rt(F)=0.892, Rd-Rt(R)=0.556
#   Class 14: O-Rd(F)=16.274, O-Rd(R)=0.079 | O-Rt(F)=6.722, O-Rt(R)=0.592 | Rd-Rt(F)=1.245, Rd-Rt(R)=0.563
#   Class 15: O-Rd(F)=20.841, O-Rd(R)=0.086 | O-Rt(F)=9.184, O-Rt(R)=0.591 | Rd-Rt(F)=1.452, Rd-Rt(R)=0.551
#   Class 19: O-Rd(F)=16.139, O-Rd(R)=0.071 | O-Rt(F)=7.293, O-Rt(R)=0.590 | Rd-Rt(F)=1.242, Rd-Rt(R)=0.556
#   Class 24: O-Rd(F)=22.692, O-Rd(R)=0.039 | O-Rt(F)=11.966, O-Rt(R)=0.583 | Rd-Rt(F)=0.845, Rd-Rt(R)=0.569
#   Class 23: O-Rd(F)=21.579, O-Rd(R)=0.049 | O-Rt(F)=9.601, O-Rt(R)=0.585 | Rd-Rt(F)=1.008, Rd-Rt(R)=0.567
#   Class 25: O-Rd(F)=15.602, O-Rd(R)=0.118 | O-Rt(F)=6.914, O-Rt(R)=0.604 | Rd-Rt(F)=1.171, Rd-Rt(R)=0.554
#   Class 29: O-Rd(F)=17.508, O-Rd(R)=0.075 | O-Rt(F)=7.181, O-Rt(R)=0.592 | Rd-Rt(F)=1.546, Rd-Rt(R)=0.559
#   Class 30: O-Rd(F)=17.322, O-Rd(R)=0.067 | O-Rt(F)=9.255, O-Rt(R)=0.597 | Rd-Rt(F)=0.939, Rd-Rt(R)=0.562
#   Class 31: O-Rd(F)=18.715, O-Rd(R)=0.070 | O-Rt(F)=8.807, O-Rt(R)=0.594 | Rd-Rt(F)=1.295, Rd-Rt(R)=0.578
#   Class 36: O-Rd(F)=22.268, O-Rd(R)=0.055 | O-Rt(F)=9.662, O-Rt(R)=0.577 | Rd-Rt(F)=1.126, Rd-Rt(R)=0.568
#   Class 35: O-Rd(F)=13.537, O-Rd(R)=0.144 | O-Rt(F)=7.175, O-Rt(R)=0.618 | Rd-Rt(F)=0.856, Rd-Rt(R)=0.553
#   Class 39: O-Rd(F)=22.603, O-Rd(R)=0.035 | O-Rt(F)=9.029, O-Rt(R)=0.585 | Rd-Rt(F)=1.510, Rd-Rt(R)=0.577
#   Class 44: O-Rd(F)=12.691, O-Rd(R)=0.193 | O-Rt(F)=5.849, O-Rt(R)=0.621 | Rd-Rt(F)=1.311, Rd-Rt(R)=0.548
#   Class 41: O-Rd(F)=23.752, O-Rd(R)=0.036 | O-Rt(F)=9.691, O-Rt(R)=0.588 | Rd-Rt(F)=1.509, Rd-Rt(R)=0.563
#   Class 49: O-Rd(F)=22.778, O-Rd(R)=0.058 | O-Rt(F)=9.500, O-Rt(R)=0.603 | Rd-Rt(F)=1.192, Rd-Rt(R)=0.577
#   Class 48: O-Rd(F)=25.280, O-Rd(R)=0.045 | O-Rt(F)=11.709, O-Rt(R)=0.591 | Rd-Rt(F)=0.896, Rd-Rt(R)=0.572
#   Class 51: O-Rd(F)=19.229, O-Rd(R)=0.071 | O-Rt(F)=7.667, O-Rt(R)=0.590 | Rd-Rt(F)=1.701, Rd-Rt(R)=0.562
#   Class 53: O-Rd(F)=24.434, O-Rd(R)=0.052 | O-Rt(F)=11.532, O-Rt(R)=0.604 | Rd-Rt(F)=0.991, Rd-Rt(R)=0.580
#   Class 59: O-Rd(F)=18.437, O-Rd(R)=0.099 | O-Rt(F)=8.107, O-Rt(R)=0.618 | Rd-Rt(F)=1.033, Rd-Rt(R)=0.576
#   Class 57: O-Rd(F)=20.336, O-Rd(R)=0.082 | O-Rt(F)=8.704, O-Rt(R)=0.599 | Rd-Rt(F)=1.139, Rd-Rt(R)=0.577
#   Class 60: O-Rd(F)=22.812, O-Rd(R)=0.047 | O-Rt(F)=9.803, O-Rt(R)=0.589 | Rd-Rt(F)=1.045, Rd-Rt(R)=0.566
#   Class 61: O-Rd(F)=18.031, O-Rd(R)=0.071 | O-Rt(F)=9.079, O-Rt(R)=0.596 | Rd-Rt(F)=0.826, Rd-Rt(R)=0.579
#   Class 68: O-Rd(F)=24.930, O-Rd(R)=0.035 | O-Rt(F)=11.536, O-Rt(R)=0.595 | Rd-Rt(F)=0.975, Rd-Rt(R)=0.591
#   Class 67: O-Rd(F)=15.075, O-Rd(R)=0.100 | O-Rt(F)=7.341, O-Rt(R)=0.595 | Rd-Rt(F)=1.002, Rd-Rt(R)=0.563
#   Class 72: O-Rd(F)=10.020, O-Rd(R)=0.164 | O-Rt(F)=5.180, O-Rt(R)=0.624 | Rd-Rt(F)=1.092, Rd-Rt(R)=0.551
#   Class 71: O-Rd(F)=22.089, O-Rd(R)=0.070 | O-Rt(F)=10.479, O-Rt(R)=0.585 | Rd-Rt(F)=0.831, Rd-Rt(R)=0.562
#   Class 76: O-Rd(F)=24.046, O-Rd(R)=0.037 | O-Rt(F)=9.687, O-Rt(R)=0.583 | Rd-Rt(F)=1.157, Rd-Rt(R)=0.566
#   Class 77: O-Rd(F)=17.350, O-Rd(R)=0.085 | O-Rt(F)=7.367, O-Rt(R)=0.598 | Rd-Rt(F)=1.424, Rd-Rt(R)=0.562
#   Class 80: O-Rd(F)=15.273, O-Rd(R)=0.128 | O-Rt(F)=7.596, O-Rt(R)=0.597 | Rd-Rt(F)=1.355, Rd-Rt(R)=0.552
#   Class 84: O-Rd(F)=17.259, O-Rd(R)=0.063 | O-Rt(F)=7.275, O-Rt(R)=0.591 | Rd-Rt(F)=1.242, Rd-Rt(R)=0.563
#   Class 88: O-Rd(F)=20.677, O-Rd(R)=0.050 | O-Rt(F)=9.388, O-Rt(R)=0.579 | Rd-Rt(F)=1.164, Rd-Rt(R)=0.558
#   Class 85: O-Rd(F)=21.850, O-Rd(R)=0.042 | O-Rt(F)=8.603, O-Rt(R)=0.587 | Rd-Rt(F)=1.441, Rd-Rt(R)=0.566
#   Class 92: O-Rd(F)=17.728, O-Rd(R)=0.093 | O-Rt(F)=8.058, O-Rt(R)=0.610 | Rd-Rt(F)=0.896, Rd-Rt(R)=0.564
#   Class 94: O-Rd(F)=24.538, O-Rd(R)=0.035 | O-Rt(F)=10.000, O-Rt(R)=0.581 | Rd-Rt(F)=1.264, Rd-Rt(R)=0.573
#   Class 99: O-Rd(F)=18.784, O-Rd(R)=0.069 | O-Rt(F)=7.914, O-Rt(R)=0.599 | Rd-Rt(F)=1.076, Rd-Rt(R)=0.567
#   Class 97: O-Rd(F)=20.106, O-Rd(R)=0.064 | O-Rt(F)=8.398, O-Rt(R)=0.599 | Rd-Rt(F)=1.399, Rd-Rt(R)=0.568
#
# === Seed 93 ===
#   Class 4: O-Rd(F)=15.345, O-Rd(R)=0.141 | O-Rt(F)=7.060, O-Rt(R)=0.622 | Rd-Rt(F)=1.049, Rd-Rt(R)=0.555
#   Class 7: O-Rd(F)=19.460, O-Rd(R)=0.076 | O-Rt(F)=8.702, O-Rt(R)=0.585 | Rd-Rt(F)=1.179, Rd-Rt(R)=0.545
#   Class 6: O-Rd(F)=21.331, O-Rd(R)=0.063 | O-Rt(F)=9.311, O-Rt(R)=0.576 | Rd-Rt(F)=1.144, Rd-Rt(R)=0.542
#   Class 11: O-Rd(F)=12.015, O-Rd(R)=0.132 | O-Rt(F)=6.754, O-Rt(R)=0.609 | Rd-Rt(F)=0.835, Rd-Rt(R)=0.541
#   Class 14: O-Rd(F)=15.983, O-Rd(R)=0.100 | O-Rt(F)=6.779, O-Rt(R)=0.583 | Rd-Rt(F)=1.272, Rd-Rt(R)=0.535
#   Class 15: O-Rd(F)=19.320, O-Rd(R)=0.076 | O-Rt(F)=8.360, O-Rt(R)=0.585 | Rd-Rt(F)=1.314, Rd-Rt(R)=0.548
#   Class 19: O-Rd(F)=16.246, O-Rd(R)=0.069 | O-Rt(F)=7.398, O-Rt(R)=0.588 | Rd-Rt(F)=1.431, Rd-Rt(R)=0.550
#   Class 24: O-Rd(F)=21.820, O-Rd(R)=0.042 | O-Rt(F)=11.677, O-Rt(R)=0.579 | Rd-Rt(F)=0.767, Rd-Rt(R)=0.552
#   Class 23: O-Rd(F)=21.489, O-Rd(R)=0.051 | O-Rt(F)=9.360, O-Rt(R)=0.582 | Rd-Rt(F)=1.176, Rd-Rt(R)=0.565
#   Class 25: O-Rd(F)=14.286, O-Rd(R)=0.111 | O-Rt(F)=6.366, O-Rt(R)=0.593 | Rd-Rt(F)=1.081, Rd-Rt(R)=0.549
#   Class 29: O-Rd(F)=18.201, O-Rd(R)=0.076 | O-Rt(F)=7.576, O-Rt(R)=0.582 | Rd-Rt(F)=1.503, Rd-Rt(R)=0.553
#   Class 30: O-Rd(F)=17.262, O-Rd(R)=0.081 | O-Rt(F)=9.318, O-Rt(R)=0.583 | Rd-Rt(F)=0.868, Rd-Rt(R)=0.539
#   Class 31: O-Rd(F)=17.771, O-Rd(R)=0.067 | O-Rt(F)=8.071, O-Rt(R)=0.592 | Rd-Rt(F)=1.240, Rd-Rt(R)=0.557
#   Class 36: O-Rd(F)=21.260, O-Rd(R)=0.056 | O-Rt(F)=9.978, O-Rt(R)=0.581 | Rd-Rt(F)=1.150, Rd-Rt(R)=0.553
#   Class 35: O-Rd(F)=12.589, O-Rd(R)=0.117 | O-Rt(F)=6.833, O-Rt(R)=0.606 | Rd-Rt(F)=0.701, Rd-Rt(R)=0.545
#   Class 39: O-Rd(F)=22.263, O-Rd(R)=0.029 | O-Rt(F)=9.156, O-Rt(R)=0.573 | Rd-Rt(F)=1.551, Rd-Rt(R)=0.559
#   Class 44: O-Rd(F)=12.095, O-Rd(R)=0.161 | O-Rt(F)=5.713, O-Rt(R)=0.602 | Rd-Rt(F)=1.391, Rd-Rt(R)=0.539
#   Class 41: O-Rd(F)=23.838, O-Rd(R)=0.036 | O-Rt(F)=9.265, O-Rt(R)=0.576 | Rd-Rt(F)=1.157, Rd-Rt(R)=0.556
#   Class 49: O-Rd(F)=22.839, O-Rd(R)=0.063 | O-Rt(F)=9.382, O-Rt(R)=0.599 | Rd-Rt(F)=1.254, Rd-Rt(R)=0.570
#   Class 48: O-Rd(F)=24.751, O-Rd(R)=0.046 | O-Rt(F)=11.730, O-Rt(R)=0.588 | Rd-Rt(F)=0.891, Rd-Rt(R)=0.556
#   Class 51: O-Rd(F)=19.072, O-Rd(R)=0.067 | O-Rt(F)=7.738, O-Rt(R)=0.594 | Rd-Rt(F)=1.520, Rd-Rt(R)=0.565
#   Class 53: O-Rd(F)=24.709, O-Rd(R)=0.049 | O-Rt(F)=11.291, O-Rt(R)=0.585 | Rd-Rt(F)=1.225, Rd-Rt(R)=0.545
#   Class 59: O-Rd(F)=18.254, O-Rd(R)=0.097 | O-Rt(F)=8.114, O-Rt(R)=0.596 | Rd-Rt(F)=0.761, Rd-Rt(R)=0.545
#   Class 57: O-Rd(F)=20.575, O-Rd(R)=0.075 | O-Rt(F)=8.514, O-Rt(R)=0.587 | Rd-Rt(F)=0.997, Rd-Rt(R)=0.554
#   Class 60: O-Rd(F)=23.001, O-Rd(R)=0.050 | O-Rt(F)=10.542, O-Rt(R)=0.597 | Rd-Rt(F)=1.107, Rd-Rt(R)=0.568
#   Class 61: O-Rd(F)=18.074, O-Rd(R)=0.075 | O-Rt(F)=8.884, O-Rt(R)=0.601 | Rd-Rt(F)=0.848, Rd-Rt(R)=0.554
#   Class 68: O-Rd(F)=25.089, O-Rd(R)=0.034 | O-Rt(F)=11.340, O-Rt(R)=0.575 | Rd-Rt(F)=0.697, Rd-Rt(R)=0.559
#   Class 67: O-Rd(F)=16.983, O-Rd(R)=0.124 | O-Rt(F)=8.297, O-Rt(R)=0.618 | Rd-Rt(F)=1.200, Rd-Rt(R)=0.551
#   Class 72: O-Rd(F)=12.547, O-Rd(R)=0.160 | O-Rt(F)=6.054, O-Rt(R)=0.607 | Rd-Rt(F)=0.999, Rd-Rt(R)=0.533
#   Class 71: O-Rd(F)=22.192, O-Rd(R)=0.063 | O-Rt(F)=10.567, O-Rt(R)=0.610 | Rd-Rt(F)=0.789, Rd-Rt(R)=0.575
#   Class 76: O-Rd(F)=24.071, O-Rd(R)=0.037 | O-Rt(F)=10.206, O-Rt(R)=0.584 | Rd-Rt(F)=1.118, Rd-Rt(R)=0.559
#   Class 77: O-Rd(F)=16.963, O-Rd(R)=0.079 | O-Rt(F)=7.098, O-Rt(R)=0.589 | Rd-Rt(F)=1.500, Rd-Rt(R)=0.549
#   Class 80: O-Rd(F)=15.560, O-Rd(R)=0.107 | O-Rt(F)=7.365, O-Rt(R)=0.598 | Rd-Rt(F)=1.357, Rd-Rt(R)=0.539
#   Class 84: O-Rd(F)=17.151, O-Rd(R)=0.060 | O-Rt(F)=7.030, O-Rt(R)=0.573 | Rd-Rt(F)=1.120, Rd-Rt(R)=0.547
#   Class 88: O-Rd(F)=21.199, O-Rd(R)=0.052 | O-Rt(F)=9.584, O-Rt(R)=0.583 | Rd-Rt(F)=1.065, Rd-Rt(R)=0.556
#   Class 85: O-Rd(F)=21.379, O-Rd(R)=0.049 | O-Rt(F)=8.326, O-Rt(R)=0.589 | Rd-Rt(F)=1.357, Rd-Rt(R)=0.556
#   Class 92: O-Rd(F)=17.431, O-Rd(R)=0.076 | O-Rt(F)=8.261, O-Rt(R)=0.605 | Rd-Rt(F)=0.882, Rd-Rt(R)=0.561
#   Class 94: O-Rd(F)=24.620, O-Rd(R)=0.038 | O-Rt(F)=9.845, O-Rt(R)=0.580 | Rd-Rt(F)=0.975, Rd-Rt(R)=0.567
#   Class 99: O-Rd(F)=18.952, O-Rd(R)=0.079 | O-Rt(F)=8.150, O-Rt(R)=0.587 | Rd-Rt(F)=1.093, Rd-Rt(R)=0.558
#   Class 97: O-Rd(F)=19.383, O-Rd(R)=0.060 | O-Rt(F)=8.112, O-Rt(R)=0.586 | Rd-Rt(F)=1.234, Rd-Rt(R)=0.553
#
# CSV saved to ../analytics/CIFAR100/kl/kl_original_retrain_redis.csv
